# %% [markdown]
#  # Navigation
#
# ---
#
# You are welcome to use this coding environment to train your agent for the project.  Follow the instructions below to get started!
#
# ### 1. Start the Environment
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!

# %%
#!pip -q install ./python
import gym

import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
import matplotlib.colors as color
# %matplotlib inline
# %load_ext autoreload
# %autoreload

# %%
#!pip -q install ./python

# %%
#!python -m pip install --upgrade pip

# %%
import cv2

# %%
from unityagents import UnityEnvironment
import numpy as np

# %%
#!python -m ipykernel install --user --name drlnd --display-name "drlnd"

# %% [markdown]
# The environment is already saved in the Workspace and can be accessed at the file path provided below.  Please run the next code cell without making any changes.

# %%
# please do not modify the line below
path = r"C:\Users\CAP Lab\Desktop\Adithya Mohan CAP_LAB\Research\RL\gym\unity\banana-visual\VisualBanana_Windows_x86_64\Banana.exe"
env = UnityEnvironment(file_name=path)
# env = UnityEnvironment(file_name="C:\Reinforcement\Banana\deep-reinforcement-learning\p1_navigation\Banana_Windows_x86_64\Banana_Windows_x86_64\Banana.exe")
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 1
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 0
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]
print(brain)
# Out:
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 1
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 0
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents in the environment
print('Number of agents:', len(env_info.agents))

# number of actions
action_size = brain.vector_action_space_size
print('Number of actions:', action_size)

# examine the state space 
state = env_info.visual_observations[0]
print('States have shape:', state.shape)
state_size = state.shape
print(state_size)
plt.imshow(np.squeeze(state))
plt.show()
state_size = state.shape
print(state.dtype , type(state))
state_Type = type(state)
print(state[:,:,:,1].shape)
torchState = torch.from_numpy(state)
print(torchState.view(84,84,3).size() , np.shape(np.squeeze(state)) ,np.shape(torchState.data.numpy()), np.shape(np.squeeze(state)) )
G = np.squeeze(state)[:,:,1]
B = np.squeeze(state)[:,:,2]
R = np.squeeze(state)[:,:,0]
temp = np.zeros(np.shape(np.squeeze(state)), dtype='float')
temp[:,:,0,] = np.squeeze(state)[:,:,0,]
plt.imshow(temp)
plt.show()
temp = np.zeros(np.shape(np.squeeze(state)), dtype='float')
temp[:,:,1,] = G
plt.imshow(temp)
plt.show()
temp = np.zeros(np.shape(np.squeeze(state)), dtype='float')
temp[:,:,2,] = B
plt.imshow(temp)
plt.show()
plt.imshow(torchState.view(84,84,3))
plt.show()
lumin = extract_luminance(np.squeeze(state))
plt.imshow(lumin)
plt.show()
lumin = scale_lumininance(np.squeeze(state))
plt.imshow(lumin)
plt.show()
img_out = np.copy(np.squeeze(state))
print("img_out" , np.shape(img_out))
#img_out = np.reshape(img_out, (3,84,84))
imghsv  = color.rgb_to_hsv(img_out)
img_cv = img_out * 255
img_cv = img_cv.astype(np.uint8)
img_cv_hsv = cv2.cvtColor(img_cv , cv2.COLOR_RGB2HSV)
print(np.shape(img_cv_hsv) , "this one " , np.shape(imghsv[:,:,0]))
plt.imshow(imghsv[:,:,2], cmap='hsv')
plt.show()
plt.imshow(img_cv_hsv[:,:,2], cmap='hsv')
plt.show()
lower_yellow = np.array([25,30,81])
upper_yellow = np.array([40,100,100])

mask = cv2.inRange(img_cv_hsv, lower_yellow, upper_yellow)
res = cv2.bitwise_and(img_cv_hsv,img_cv_hsv, mask= mask)
plt.imshow(mask , cmap = "hsv")
plt.show()
plt.imshow(res , cmap = "hsv")
plt.show()
# Out:
# Number of agents: 1
# Number of actions: 4
# States have shape: (1, 84, 84, 3)
# (1, 84, 84, 3)
# float64 <class 'numpy.ndarray'>
# (1, 84, 84)
# torch.Size([84, 84, 3]) (84, 84, 3) (1, 84, 84, 3) (84, 84, 3)
# img_out (84, 84, 3)
# (84, 84, 3) this one  (84, 84)

# %%
def extract_luminance(image):
    luminance = np.sqrt(0.299*np.power(image[:,:,0],2) + 0.587*np.power(image[:,:,1],2) + 0.114*np.power(image[:,:,2],2))
    return luminance
def scale_lumininance(img):
    return np.dot(img[...,:3], [0.2126, 0.0152, 0.722])

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Note that **in this coding environment, you will not be able to watch the agent while it is training**, and you should set `train_mode=True` to restart the environment.

# %%
env_info = env.reset(train_mode=True)[brain_name] # reset the environment
state = env_info.vector_observations[0]            # get the current state
score = 0                                          # initialize the score
while True:
    action = np.random.randint(action_size)        # select an action
    env_info = env.step(action)[brain_name]        # send the action to the environment
    next_state = env_info.vector_observations[0]   # get the next state
    #print(len(next_state))
    reward = env_info.rewards[0]                   # get the reward
    done = env_info.local_done[0]                  # see if episode has finished
    score += reward                                # update the score
    state = next_state                             # roll over the state to next time step
    if done:                                       # exit loop if episode finished
        break
    
print("Score: {}".format(score))
# Out:
# Score: 1.0

# %%
import numpy as np
import random
from collections import namedtuple, deque
from queue import PriorityQueue

from model import QNetwork
from model import QNetworkCNN
from torch.autograd import Variable

import torch
import torch.nn.functional as F
import torch.optim as optim

# %%
import torchvision.transforms as transforms

# %%
BUFFER_SIZE = int(1e4)  # replay buffer size
BATCH_SIZE = 16       # minibatch size
GAMMA = 0.99           # discount factor
TAU = 1e-3              # for soft update of target parameters
LR = 8e-4               # learning rate 

WeightDecay = 1e-4

UPDATE_EVERY = 1      # how often to update the network
N_Update_per = 1 # no of updates per time

Momentum = 0.9  
Epislon = 0.99
min_Epislon = 0.001

Decay = 0.99
MaxBeta = 1
MinBeta = 0


ALPHA = 0.5
ALPHA2 = 1
ALPHA_min = 0.01
Alphadecay = 0.999 
ErrorOffset = 0.01
min_beta = 0.3

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device which is used is " , device)
print("cuda available", torch.cuda.is_available())
#a = torch.cuda.FloatTensor([1.])
b = torch.tensor([ 1.], device='cuda:0')
# Out:
# Device which is used is  cuda:0
# cuda available True

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device which is used is " , device)

class Agent():
    """Interacts with and learns from the environment."""

    def __init__(self, state_size, action_size, state_type,seed ,  visual = False):
        """Initialize an Agent object.
        
        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            seed (int): random seed
            Beta is for sacling down the weights update due to the Priority Queues
        """
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)
        self.Beta = 1
        self.Gamma = GAMMA

        # Q-Network
        if(not visual):
            self.qnetwork_local = QNetwork(state_size, action_size, seed ).to(device)
            self.qnetwork_target = QNetwork(state_size, action_size, seed ).to(device)
        else:
            self.qnetwork_local = QNetworkCNN(state_size, action_size, seed , augment_frames = 3).to(device)
            self.qnetwork_target = QNetworkCNN(state_size, action_size, seed , augment_frames = 3).to(device)
            
        
        self.optimizer = optim.Adam(self.qnetwork_local.parameters(), lr=LR , weight_decay= WeightDecay)
        self.state_type = state_type
        # Replay memory
        #self.memory = PriorityReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE,ALPHA,state_type, seed)
        self.memory = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, seed)
        # Initialize time step (for updating every UPDATE_EVERY steps)
        self.t_step = 0
        
    
    def step(self, state, action, reward, next_state, done):
        # Save experience in replay memory
        #Priority = self.getError(state, action, reward, next_state,done)
        #self.memory.add(state, action, reward, next_state, done,Priority)
        #self, state, action, reward, next_state, done
        self.memory.add(state, action, reward, next_state,done)
        global Epislon
        Epislon *= Decay
        if(Epislon < min_Epislon):
            Epislon = min_Epislon
        beta = 1 - Epislon
        #print(beta)
        # alpha value for priority buffer
        global ALPHA2
        ALPHA2 *= Alphadecay
        if(ALPHA2 < ALPHA_min):
            ALPHA2 = ALPHA_min
        
        # Learn every UPDATE_EVERY time steps.
        self.t_step = (self.t_step + 1) % UPDATE_EVERY
        if self.t_step == 0:
            # If enough samples are available in memory, get random subset and learn
            if len(self.memory) > BATCH_SIZE:
                #uncomment this for priority buffer
                #experiences = self.memory.sample(ALPHA2,beta)
                for _ in range(N_Update_per):
                    experiences = self.memory.sample_idx()
                    self.learn(experiences, GAMMA)

    def act(self, state, eps=0.):
        """Returns actions for given state as per current policy.
        
        Params
        ======
            state (array_like): current state
            eps (float): epsilon, for epsilon-greedy action selection
        """
        
        #state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        # if e is not None and e[1].done != True and 
        # self.memory[e[0]-1].done != True and e[0]-1 > 0 and e[0] < len(agent.memory.memory)-1])
        if (len(self.memory.memory) >= 2 and (self.memory.memory[-1].done or self.memory.memory[-2].done) == False):
            #print(np.dtype(state), np.size(state))
            state = torch.from_numpy(np.array([self.memory.memory[-2].state,self.memory.memory[-1].state,state])).float().view(1,-1,84,84).to(device)
            
            self.qnetwork_local.eval()
            #print(np.size(state))
            with torch.no_grad():
                action_values = self.qnetwork_local(state)
            #print(action_values)
            self.qnetwork_local.train()
            #for debuging
            #check =    random.choice(np.arange(self.action_size))
            #check2 = np.argmax(action_values.cpu().data.numpy())
            #print(check.dtype , check2.dtype)
            # Epsilon-greedy action selection
            if random.random() > eps:
                return np.argmax(action_values.cpu().data.numpy() , )
            else:
                return random.choice(np.arange(self.action_size))
        else:
            return random.choice(np.arange(self.action_size))
            
                   

    def learn(self, experiences, gamma):
        """Update value parameters using given batch of experience tuples.

        Params
        ======
            experiences (Tuple[torch.Variable]): tuple of (s, a, r, s', done) tuples 
            gamma (float): discount factor
        """
        
        
        #states, actions, rewards, next_states, dones, weights = experiences
        states, actions, rewards, next_states, dones = experiences
        #print(states.size())
        size_now = states.size()
        states = states.view(size_now[0] , -1 , 84 , 84)
        next_states = next_states.view(size_now[0] , -1 , 84 , 84)
        # Get max predicted Q values (for next states) from target model
        #getting the maximum action from the Q table and applying it in the 
        #print("states size" , next_states.size())
        #------this for DDQN ---- uncomment this for DDQN-------------------------
        Q_targets_next_action = self.qnetwork_local(next_states).detach().argmax(1).unsqueeze(1)
        #print(Q_targets_next_action)
        Q_targets_next = self.qnetwork_target(next_states).gather(1 , Q_targets_next_action)
        Q_targets_next = Q_targets_next.detach()
        # Compute Q targets for current states 
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))

        # Get expected Q values from local model
        Q_expected = self.qnetwork_local(states).gather(1, actions)
        #print("expected" , Q_expected , Q_targets)
        # Compute loss
        loss = F.mse_loss(Q_expected, Q_targets)
        # change reduce to False for priority buffer
        
        #loss = F.smooth_l1_loss(Q_expected, Q_targets)
        #print(loss.size())
        
        # this removed due to the swtching to normal replay buffer
        #loss = loss * (weights).detach()
        #loss = torch.mean(loss)
        #loss has to be scaled scaled down by weights = (1 /(N*p(i)))^Beta
        #loss = F.l1_loss(Q_expected , Q_targets)
        
        #print("The Loss", loss)
        # Minimize the loss
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
        
        

        # ------------------- update target network ------------------- #
        self.soft_update(self.qnetwork_local, self.qnetwork_target, TAU)
        
#         ##-- for updating the priorities in the experience replay buffer------###
#         with torch.no_grad():
#             Q_targets_next_action = self.qnetwork_local(next_states).detach().max(1)[1].unsqueeze(1)
#             #print(Q_targets_next_action)
#             Q_targets_next = self.qnetwork_target(next_states).gather(1 , Q_targets_next_action)
#             Q_targets_next = Q_targets_next.detach()
#             # Compute Q targets for current states 
#             Q_targets = rewards + (gamma * Q_targets_next * (1 - dones)).detach()

#             # Get expected Q values from local model
#             Q_expected = self.qnetwork_local(states).gather(1, actions).detach()

#             errors = torch.abs(Q_expected - Q_targets).cpu().data.numpy()
#             self.memory.updatePriorities(errors)
        
        
        
    def ConvnumpyTotorch(self,states, actions, rewards, next_states, dones):
        # converts the numpy to tensor variables
        states = torch.from_numpy(np.array([states])).float().to(device)
        actions = torch.from_numpy(np.array([[actions]])).long().to(device)
        rewards = torch.from_numpy(np.array([rewards])).float().to(device)
        next_states = torch.from_numpy(np.array([next_states])).float().to(device)
        dones = torch.from_numpy(np.array([dones]).astype(np.uint8)).float().to(device)
        return states, actions, rewards, next_states, dones
        
    def getError(self,states, actions, rewards, next_states, dones):
        
        with torch.no_grad():
            #print("states" , states.shape , next_states.shape)
            states, actions, rewards, next_states, dones = self.ConvnumpyTotorch(states, actions, rewards, next_states, dones)
            #print("states",states , next_states)
            Q_targets_next_action = self.qnetwork_local(next_states).detach().max(1)[1].unsqueeze(1)
            #print("actions",Q_targets_next_action , actions)
            #print(next_states.shape)
            Q_targets_next = self.qnetwork_target(next_states).gather(1 , Q_targets_next_action)
            Q_targets_next = Q_targets_next.detach()
            # Compute Q targets for current states 
            Q_targets = rewards + (GAMMA * Q_targets_next * (1 - dones))

            # Get expected Q values from local model

            Q_expected = self.qnetwork_local(states).gather(1, actions)
            Q_expected = Q_expected.detach()
            #error =  F.l1_loss(Q_expected , Q_targets)
            error =  torch.abs(Q_expected - Q_targets).cpu().data.numpy()
        return (error.item() + ErrorOffset)
    
    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target

        Params
        ======
            local_model (PyTorch model): weights will be copied from
            target_model (PyTorch model): weights will be copied to
            tau (float): interpolation parameter 
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)


class ReplayBuffer:
    """Fixed-size buffer to store experience tuples. 
    Also can be used to store the priortized tuples"""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.

        Params
        ======
            action_size (int): dimension of each action
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
            Priority(float):
            seed (int): random seed
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)  
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
        self.selectedIdx = np.array([])
    
    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)
    
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)
        #print(experiences[0])
        states = torch.from_numpy(np.stack([e.state for e in experiences if e is not None] , axis =0 )).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.stack([e.next_state for e in experiences if e is not None], axis =0)).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)
  
        return (states, actions, rewards, next_states, dones)
    def sample_idx(self):
        index_value = random.sample(list(enumerate(self.memory)), k=self.batch_size)
        #print("batch", self.batch_size)
        states = torch.from_numpy(np.stack([[self.memory[e[0]-2].state,self.memory[e[0]-1].state ,e[1].state] for e in index_value if e is not None and e[1].done != True and self.memory[e[0]-1].done != True and e[0]-1 > 0 and e[0] < len(agent.memory.memory)-1] , axis = 0 )).float().to(device)
        actions = torch.from_numpy(np.vstack([e[1].action for e in index_value if e is not None and e[1].done != True and self.memory[e[0]-1].done != True and e[0]-1 > 0 and e[0] < len(agent.memory.memory)-1])).long().to(device)
        rewards = torch.from_numpy(np.vstack([e[1].reward for e in index_value if e is not None and e[1].done != True and self.memory[e[0]-1].done != True and e[0]-1 > 0 and e[0] < len(agent.memory.memory)-1])).float().to(device)
        next_states = torch.from_numpy(np.stack([[self.memory[e[0]-2].next_state, self.memory[e[0]-1].next_state ,e[1].next_state] for e in index_value if e is not None and e[1].done != True and self.memory[e[0]-1].done != True and e[0]-1 > 0 and e[0] < len(agent.memory.memory)-1] , axis = 0 )).float().to(device)
        dones = torch.from_numpy(np.vstack([e[1].done for e in index_value if e is not None and e[1].done != True and self.memory[e[0]-1].done != True and e[0]-1 > 0 and e[0] < len(agent.memory.memory)-1]).astype(np.uint8)).float().to(device)
        
        return (states, actions, rewards, next_states, dones)
    
    def sample_idx_withBatch(self , batch_size):
        
        
        index_value = random.sample(list(enumerate(self.memory)), k=batch_size)
        states = torch.from_numpy(np.stack([[self.memory[e[0]-1].state ,e[1].state] for e in index_value if e is not None and e[1].done != True and self.memory[e[0]-1].done != True] , axis = 0 )).float().to(device)
        actions = torch.from_numpy(np.vstack([e[1].action for e in index_value if e is not None and e[1].done != True and self.memory[e[0]-1].done != True])).long().to(device)
        rewards = torch.from_numpy(np.vstack([e[1].reward for e in index_value if e is not None and e[1].done != True and self.memory[e[0]-1].done != True])).float().to(device)
        next_states = torch.from_numpy(np.stack([[self.memory[e[0]-1].state ,e[1].state] for e in index_value if e is not None and e[1].done != True and self.memory[e[0]-1].done != True] , axis = 0 )).float().to(device)
        dones = torch.from_numpy(np.vstack([e[1].done for e in index_value if e is not None and e[1].done != True and self.memory[e[0]-1].done != True]).astype(np.uint8)).float().to(device)
        
        return (states, actions, rewards, next_states, dones)
    
        



    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)
    
class PriorityReplayBuffer:
    """Fixed-size buffer to store experience tuples. 
    Also can be used to store the priortized tuples"""

    def __init__(self, action_size, buffer_size, batch_size, alpha, state_type ,  seed):
        """Initialize a ReplayBuffer object.

        Params
        ======
            action_size (int): dimension of each action
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
            Priority(float):
            seed (int): random seed
        """
        self.action_size = action_size
        self.Prioritymemory = deque(maxlen=buffer_size) 
        self.batch_size = batch_size
        self.expType = [('state',state_type), ('action','float'),('reward','float'), ('next_state',state_type),('done','bool'),('Priority','float')]
        self.experienceMemory = np.array([], dtype = self.expType)
        self.seed = random.seed(seed)
        self.max_size = buffer_size
        self.alpha = alpha
        
    
    def add(self, state, action, reward, next_state, done, Priority):
        """Add a new experience to memory."""
        if(np.size(self.experienceMemory) > self.max_size):
            self.experienceMemory = np.delete(self.experienceMemory , 0 )
        e = (state, action, reward, next_state, done, Priority)
        exp = np.array([e] , dtype = self.expType)
        self.experienceMemory = np.append(self.experienceMemory , exp )
        #print("memory", np.shape(self.experienceMemory['state'][0]))
        #self.memory.append(e)
    
    def sample(self , alpha , beta):
        """ sample a batch of experiences from memory. based on the Priority"""
        # write ur own implementation
        self.alpha = alpha
        self.beta = beta
        if(self.beta < min_beta):
            self.beta = min_beta
        probs ,Choosenindex = self.Batchsample()
        self.selectedIdx = Choosenindex
        weights = (np.size(self.experienceMemory)* probs)**(-(self.beta))
        weights /= np.max(weights)
        weights = Variable(torch.from_numpy(np.vstack(weights)).float().to(device))
        states = Variable(torch.from_numpy(np.stack(self.experienceMemory['state'][Choosenindex] , axis =0)).float().to(device))
        #print("at sampling",states.size())
        actions = Variable(torch.from_numpy(np.vstack(self.experienceMemory['action'][Choosenindex])).long().to(device))
        rewards = Variable(torch.from_numpy(np.vstack(self.experienceMemory['reward'][Choosenindex])).float().to(device))
        next_states = Variable(torch.from_numpy(np.stack(self.experienceMemory['next_state'][Choosenindex] , axis =0)).float().to(device))
        dones = Variable(torch.from_numpy(np.vstack(self.experienceMemory['done'][Choosenindex]).astype(np.uint8)).float().to(device))
        
        
  
        return (states, actions, rewards, next_states, dones , weights)
    
    def Batchsample(self):
        """Samples the batch here """
        all_priorities = self.experienceMemory['Priority']
        probs = self.GetProbs(all_priorities)
        indeArr = np.arange(len(probs))
        Choosenindex = np.random.choice(indeArr, self.batch_size,p=probs, replace = False)
        return probs[Choosenindex] , Choosenindex
    
    def GetProbs(self, Pri):
        """ Probabilities are defiend here"""
        Numerator = np.power(Pri, self.alpha)
        Demoninator = np.sum(Numerator)
        Probs = Numerator / Demoninator
        return Probs
    
    def updatePriorities(self,Error):
        #print(self.selectedIdx , Error , np.size(Error) , np.size(self.selectedIdx))
        self.experienceMemory['Priority'][self.selectedIdx] = Error.flatten()
                                    
    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.experienceMemory)
# Out:
# Device which is used is  cuda:0

# %%
# print(np.shape(np.stack(agent.memory.experienceMemory['state'][np.array([1,2])], axis = 0) ))
# #this is where the issue is 
# ## debug block here 
# a = np.array(3)
# a =np.int64(a)
# print(a.dtype)
a  = [[i , i+2 ] for i in range(10)]
a
# Out:
# [[0, 2],
#  [1, 3],
#  [2, 4],
#  [3, 5],
#  [4, 6],
#  [5, 7],
#  [6, 8],
#  [7, 9],
#  [8, 10],
#  [9, 11]]

# %%
#from dqn_agent import Agent
agent = Agent(state_size=(84, 84, 3), action_size=4, state_type = state_Type, visual = True, seed=0)

# %%
def extract_luminance_state(image):
    luminance = np.sqrt(0.299*np.power(image[:,:,0],2) + 0.587*np.power(image[:,:,1],2) + 0.114*np.power(image[:,:,2],2))

# %%
def dqn(n_episodes=3000, max_t=10000, eps_start=1.0, eps_end=0.01, eps_decay=0.999):
    """Deep Q-Learning.
    
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        eps_start (float): starting value of epsilon, for epsilon-greedy action selection
        eps_end (float): minimum value of epsilon
        eps_decay (float): multiplicative factor (per episode) for decreasing epsilon
    """
    scores = []                        # list containing scores from each episode
    scores_window = deque(maxlen=100)  # last 100 scores
    eps = eps_start# initialize epsilon
    Max_t = 0
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]
        s = np.squeeze(env_info.visual_observations[0])      
        state = np.resize(s , (3,84,84))
       
        score = 0
        #print("hello")
        for t in range(max_t):
            action = agent.act(state, eps)
            #print(action.dtype)
            action = np.int32(action)
            env_info = env.step(action)[brain_name]
            next_state = np.resize(env_info.visual_observations[0] , (3,84,84))
            #print(next_state.shape)
            reward = env_info.rewards[0]
            done = env_info.local_done[0]
            agent.step(state, action, reward, next_state, done)
            #print(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done:
                Max_t = t
                break 
        scores_window.append(score)       # save most recent score
        scores.append(score)              # save most recent score
        eps = max(eps_end, eps_decay*eps) # decrease epsilon
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)), end="")
        print("Maxi" ,Max_t)
        if i_episode % 1 == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)))
        if np.mean(scores_window)>=16.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode-100, np.mean(scores_window)))
            torch.save(agent.qnetwork_local.state_dict(), 'checkpoint.pth')
            if np.mean(scores_window)>=16.0:
                break
    return scores

scores = dqn()

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Episode 1	Average Score: 3.00Maxi 299
# Episode 1	Average Score: 3.00
# Episode 2	Average Score: 1.50Maxi 299
# Episode 2	Average Score: 1.50
# Episode 3	Average Score: 0.33Maxi 299
# Episode 3	Average Score: 0.33
# Episode 4	Average Score: 0.50Maxi 299
# Episode 4	Average Score: 0.50
# Episode 5	Average Score: 0.60Maxi 299
# Episode 5	Average Score: 0.60
# Episode 6	Average Score: 0.67Maxi 299
# Episode 6	Average Score: 0.67
# Episode 7	Average Score: 0.57Maxi 299
# Episode 7	Average Score: 0.57
# Episode 8	Average Score: 0.38Maxi 299
# Episode 8	Average Score: 0.38
# Episode 9	Average Score: 0.11Maxi 299
# Episode 9	Average Score: 0.11
# Episode 10	Average Score: 0.10Maxi 299
# Episode 10	Average Score: 0.10
# Episode 11	Average Score: 0.00Maxi 299
# Episode 11	Average Score: 0.00
# Episode 12	Average Score: -0.17Maxi 299
# Episode 12	Average Score: -0.17
# Episode 13	Average Score: -0.31Maxi 299
# Episode 13	Average Score: -0.31
# Episode 14	Average Score: -0.21Maxi 299
# Episode 14	Average Score: -0.21
# Episode 15	Average Score: -0.27Maxi 299
# Episode 15	Average Score: -0.27
# Episode 16	Average Score: -0.44Maxi 299
# Episode 16	Average Score: -0.44
# Episode 17	Average Score: -0.35Maxi 299
# Episode 17	Average Score: -0.35
# Episode 18	Average Score: -0.33Maxi 299
# Episode 18	Average Score: -0.33
# Episode 19	Average Score: -0.32Maxi 299
# Episode 19	Average Score: -0.32
# Episode 20	Average Score: -0.30Maxi 299
# Episode 20	Average Score: -0.30
# Episode 21	Average Score: -0.29Maxi 299
# Episode 21	Average Score: -0.29
# Episode 22	Average Score: -0.36Maxi 299
# Episode 22	Average Score: -0.36
# Episode 23	Average Score: -0.35Maxi 299
# Episode 23	Average Score: -0.35
# Episode 24	Average Score: -0.21Maxi 299
# Episode 24	Average Score: -0.21
# Episode 25	Average Score: -0.24Maxi 299
# Episode 25	Average Score: -0.24
# Episode 26	Average Score: -0.15Maxi 299
# Episode 26	Average Score: -0.15
# Episode 27	Average Score: -0.11Maxi 299
# Episode 27	Average Score: -0.11
# Episode 28	Average Score: -0.07Maxi 299
# Episode 28	Average Score: -0.07
# Episode 29	Average Score: -0.03Maxi 299
# Episode 29	Average Score: -0.03
# Episode 30	Average Score: 0.00Maxi 299
# Episode 30	Average Score: 0.00
# Episode 31	Average Score: 0.03Maxi 299
# Episode 31	Average Score: 0.03
# Episode 32	Average Score: 0.03Maxi 299
# Episode 32	Average Score: 0.03
# Episode 33	Average Score: 0.03Maxi 299
# Episode 33	Average Score: 0.03
# Episode 34	Average Score: 0.03Maxi 299
# Episode 34	Average Score: 0.03
# Episode 35	Average Score: 0.06Maxi 299
# Episode 35	Average Score: 0.06
# Episode 36	Average Score: 0.03Maxi 299
# Episode 36	Average Score: 0.03
# Episode 37	Average Score: -0.08Maxi 299
# Episode 37	Average Score: -0.08
# Episode 38	Average Score: -0.08Maxi 299
# Episode 38	Average Score: -0.08
# Episode 39	Average Score: -0.05Maxi 299
# Episode 39	Average Score: -0.05
# Episode 40	Average Score: -0.03Maxi 299
# Episode 40	Average Score: -0.03
# Episode 41	Average Score: -0.05Maxi 299
# Episode 41	Average Score: -0.05
# Episode 42	Average Score: -0.02Maxi 299
# Episode 42	Average Score: -0.02
# Episode 43	Average Score: -0.05Maxi 299
# Episode 43	Average Score: -0.05
# Episode 44	Average Score: -0.02Maxi 299
# Episode 44	Average Score: -0.02
# Episode 45	Average Score: 0.02Maxi 299
# Episode 45	Average Score: 0.02
# Episode 46	Average Score: 0.02Maxi 299
# Episode 46	Average Score: 0.02
# Episode 47	Average Score: 0.02Maxi 299
# Episode 47	Average Score: 0.02
# Episode 48	Average Score: 0.02Maxi 299
# Episode 48	Average Score: 0.02
# Episode 49	Average Score: 0.04Maxi 299
# Episode 49	Average Score: 0.04
# Episode 50	Average Score: 0.04Maxi 299
# Episode 50	Average Score: 0.04
# Episode 51	Average Score: 0.06Maxi 299
# Episode 51	Average Score: 0.06
# Episode 52	Average Score: 0.06Maxi 299
# Episode 52	Average Score: 0.06
# Episode 53	Average Score: 0.08Maxi 299
# Episode 53	Average Score: 0.08
# Episode 54	Average Score: 0.13Maxi 299
# Episode 54	Average Score: 0.13
# Episode 55	Average Score: 0.15Maxi 299
# Episode 55	Average Score: 0.15
# Episode 56	Average Score: 0.14Maxi 299
# Episode 56	Average Score: 0.14
# Episode 57	Average Score: 0.16Maxi 299
# Episode 57	Average Score: 0.16
# Episode 58	Average Score: 0.14Maxi 299
# Episode 58	Average Score: 0.14
# Episode 59	Average Score: 0.15Maxi 299
# Episode 59	Average Score: 0.15
# Episode 60	Average Score: 0.13Maxi 299
# Episode 60	Average Score: 0.13
# Episode 61	Average Score: 0.15Maxi 299
# Episode 61	Average Score: 0.15
# Episode 62	Average Score: 0.15Maxi 299
# Episode 62	Average Score: 0.15
# Episode 63	Average Score: 0.16Maxi 299
# Episode 63	Average Score: 0.16
# Episode 64	Average Score: 0.20Maxi 299
# Episode 64	Average Score: 0.20
# Episode 65	Average Score: 0.20Maxi 299
# Episode 65	Average Score: 0.20
# Episode 66	Average Score: 0.21Maxi 299
# Episode 66	Average Score: 0.21
# Episode 67	Average Score: 0.21Maxi 299
# Episode 67	Average Score: 0.21
# Episode 68	Average Score: 0.21Maxi 299
# Episode 68	Average Score: 0.21
# Episode 69	Average Score: 0.22Maxi 299
# Episode 69	Average Score: 0.22
# Episode 70	Average Score: 0.21Maxi 299
# Episode 70	Average Score: 0.21
# Episode 71	Average Score: 0.21Maxi 299
# Episode 71	Average Score: 0.21
# Episode 72	Average Score: 0.19Maxi 299
# Episode 72	Average Score: 0.19
# Episode 73	Average Score: 0.18Maxi 299
# Episode 73	Average Score: 0.18
# Episode 74	Average Score: 0.16Maxi 299
# Episode 74	Average Score: 0.16
# Episode 75	Average Score: 0.15Maxi 299
# Episode 75	Average Score: 0.15
# Episode 76	Average Score: 0.13Maxi 299
# Episode 76	Average Score: 0.13
# Episode 77	Average Score: 0.14Maxi 299
# Episode 77	Average Score: 0.14
# Episode 78	Average Score: 0.14Maxi 299
# Episode 78	Average Score: 0.14
# Episode 79	Average Score: 0.13Maxi 299
# Episode 79	Average Score: 0.13
# Episode 80	Average Score: 0.12Maxi 299
# Episode 80	Average Score: 0.12
# Episode 81	Average Score: 0.15Maxi 299
# Episode 81	Average Score: 0.15
# Episode 82	Average Score: 0.16Maxi 299
# Episode 82	Average Score: 0.16
# Episode 83	Average Score: 0.19Maxi 299
# Episode 83	Average Score: 0.19
# Episode 84	Average Score: 0.19Maxi 299
# Episode 84	Average Score: 0.19
# Episode 85	Average Score: 0.18Maxi 299
# Episode 85	Average Score: 0.18
# Episode 86	Average Score: 0.16Maxi 299
# Episode 86	Average Score: 0.16
# Episode 87	Average Score: 0.16Maxi 299
# Episode 87	Average Score: 0.16
# Episode 88	Average Score: 0.16Maxi 299
# Episode 88	Average Score: 0.16
# Episode 89	Average Score: 0.15Maxi 299
# Episode 89	Average Score: 0.15
# Episode 90	Average Score: 0.13Maxi 299
# Episode 90	Average Score: 0.13
# Episode 91	Average Score: 0.14Maxi 299
# Episode 91	Average Score: 0.14
# Episode 92	Average Score: 0.12Maxi 299
# Episode 92	Average Score: 0.12
# Episode 93	Average Score: 0.11Maxi 299
# Episode 93	Average Score: 0.11
# Episode 94	Average Score: 0.12Maxi 299
# Episode 94	Average Score: 0.12
# Episode 95	Average Score: 0.13Maxi 299
# Episode 95	Average Score: 0.13
# Episode 96	Average Score: 0.10Maxi 299
# Episode 96	Average Score: 0.10
# Episode 97	Average Score: 0.11Maxi 299
# Episode 97	Average Score: 0.11
# Episode 98	Average Score: 0.11Maxi 299
# Episode 98	Average Score: 0.11
# Episode 99	Average Score: 0.11Maxi 299
# Episode 99	Average Score: 0.11
# Episode 100	Average Score: 0.11Maxi 299
# Episode 100	Average Score: 0.11
# Episode 101	Average Score: 0.08Maxi 299
# Episode 101	Average Score: 0.08
# Episode 102	Average Score: 0.08Maxi 299
# Episode 102	Average Score: 0.08
# Episode 103	Average Score: 0.10Maxi 299
# Episode 103	Average Score: 0.10
# Episode 104	Average Score: 0.08Maxi 299
# Episode 104	Average Score: 0.08
# Episode 105	Average Score: 0.07Maxi 299
# Episode 105	Average Score: 0.07
# Episode 106	Average Score: 0.07Maxi 299
# Episode 106	Average Score: 0.07
# Episode 107	Average Score: 0.07Maxi 299
# Episode 107	Average Score: 0.07
# Episode 108	Average Score: 0.09Maxi 299
# Episode 108	Average Score: 0.09
# Episode 109	Average Score: 0.09Maxi 299
# Episode 109	Average Score: 0.09
# Episode 110	Average Score: 0.09Maxi 299
# Episode 110	Average Score: 0.09
# Episode 111	Average Score: 0.12Maxi 299
# Episode 111	Average Score: 0.12
# Episode 112	Average Score: 0.14Maxi 299
# Episode 112	Average Score: 0.14
# Episode 113	Average Score: 0.16Maxi 299
# Episode 113	Average Score: 0.16
# Episode 114	Average Score: 0.15Maxi 299
# Episode 114	Average Score: 0.15
# Episode 115	Average Score: 0.17Maxi 299
# Episode 115	Average Score: 0.17
# Episode 116	Average Score: 0.19Maxi 299
# Episode 116	Average Score: 0.19
# Episode 117	Average Score: 0.19Maxi 299
# Episode 117	Average Score: 0.19
# Episode 118	Average Score: 0.18Maxi 299
# Episode 118	Average Score: 0.18
# Episode 119	Average Score: 0.19Maxi 299
# Episode 119	Average Score: 0.19
# Episode 120	Average Score: 0.20Maxi 299
# Episode 120	Average Score: 0.20
# Episode 121	Average Score: 0.20Maxi 299
# Episode 121	Average Score: 0.20
# Episode 122	Average Score: 0.21Maxi 299
# Episode 122	Average Score: 0.21
# Episode 123	Average Score: 0.21Maxi 299
# Episode 123	Average Score: 0.21
# Episode 124	Average Score: 0.15Maxi 299
# Episode 124	Average Score: 0.15
# Episode 125	Average Score: 0.13Maxi 299
# Episode 125	Average Score: 0.13
# Episode 126	Average Score: 0.11Maxi 299
# Episode 126	Average Score: 0.11
# Episode 127	Average Score: 0.11Maxi 299
# Episode 127	Average Score: 0.11
# Episode 128	Average Score: 0.10Maxi 299
# Episode 128	Average Score: 0.10
# Episode 129	Average Score: 0.11Maxi 299
# Episode 129	Average Score: 0.11
# Episode 130	Average Score: 0.10Maxi 299
# Episode 130	Average Score: 0.10
# Episode 131	Average Score: 0.10Maxi 299
# Episode 131	Average Score: 0.10
# Episode 132	Average Score: 0.12Maxi 299
# Episode 132	Average Score: 0.12
# Episode 133	Average Score: 0.14Maxi 299
# Episode 133	Average Score: 0.14
# Episode 134	Average Score: 0.15Maxi 299
# Episode 134	Average Score: 0.15
# Episode 135	Average Score: 0.16Maxi 299
# Episode 135	Average Score: 0.16
# Episode 136	Average Score: 0.17Maxi 299
# Episode 136	Average Score: 0.17
# Episode 137	Average Score: 0.23Maxi 299
# Episode 137	Average Score: 0.23
# Episode 138	Average Score: 0.23Maxi 299
# Episode 138	Average Score: 0.23
# Episode 139	Average Score: 0.22Maxi 299
# Episode 139	Average Score: 0.22
# Episode 140	Average Score: 0.22Maxi 299
# Episode 140	Average Score: 0.22
# Episode 141	Average Score: 0.23Maxi 299
# Episode 141	Average Score: 0.23
# Episode 142	Average Score: 0.21Maxi 299
# Episode 142	Average Score: 0.21
# Episode 143	Average Score: 0.23Maxi 299
# Episode 143	Average Score: 0.23
# Episode 144	Average Score: 0.23Maxi 299
# Episode 144	Average Score: 0.23
# Episode 145	Average Score: 0.22Maxi 299
# Episode 145	Average Score: 0.22
# Episode 146	Average Score: 0.22Maxi 299
# Episode 146	Average Score: 0.22
# Episode 147	Average Score: 0.23Maxi 299
# Episode 147	Average Score: 0.23
# Episode 148	Average Score: 0.23Maxi 299
# Episode 148	Average Score: 0.23
# Episode 149	Average Score: 0.25Maxi 299
# Episode 149	Average Score: 0.25
# Episode 150	Average Score: 0.24Maxi 299
# Episode 150	Average Score: 0.24
# Episode 151	Average Score: 0.23Maxi 299
# Episode 151	Average Score: 0.23
# Episode 152	Average Score: 0.24Maxi 299
# Episode 152	Average Score: 0.24
# Episode 153	Average Score: 0.23Maxi 299
# Episode 153	Average Score: 0.23
# Episode 154	Average Score: 0.20Maxi 299
# Episode 154	Average Score: 0.20
# Episode 155	Average Score: 0.16Maxi 299
# Episode 155	Average Score: 0.16
# Episode 156	Average Score: 0.16Maxi 299
# Episode 156	Average Score: 0.16
# Episode 157	Average Score: 0.15Maxi 299
# Episode 157	Average Score: 0.15
# Episode 158	Average Score: 0.15Maxi 299
# Episode 158	Average Score: 0.15
# Episode 159	Average Score: 0.15Maxi 299
# Episode 159	Average Score: 0.15
# Episode 160	Average Score: 0.17Maxi 299
# Episode 160	Average Score: 0.17
# Episode 161	Average Score: 0.16Maxi 299
# Episode 161	Average Score: 0.16
# Episode 162	Average Score: 0.17Maxi 299
# Episode 162	Average Score: 0.17
# Episode 163	Average Score: 0.17Maxi 299
# Episode 163	Average Score: 0.17
# Episode 164	Average Score: 0.14Maxi 299
# Episode 164	Average Score: 0.14
# Episode 165	Average Score: 0.16Maxi 299
# Episode 165	Average Score: 0.16
# Episode 166	Average Score: 0.17Maxi 299
# Episode 166	Average Score: 0.17
# Episode 167	Average Score: 0.17Maxi 299
# Episode 167	Average Score: 0.17
# Episode 168	Average Score: 0.16Maxi 299
# Episode 168	Average Score: 0.16
# Episode 169	Average Score: 0.17Maxi 299
# Episode 169	Average Score: 0.17
# Episode 170	Average Score: 0.21Maxi 299
# Episode 170	Average Score: 0.21
# Episode 171	Average Score: 0.20Maxi 299
# Episode 171	Average Score: 0.20
# Episode 172	Average Score: 0.21Maxi 299
# Episode 172	Average Score: 0.21
# Episode 173	Average Score: 0.21Maxi 299
# Episode 173	Average Score: 0.21
# Episode 174	Average Score: 0.21Maxi 299
# Episode 174	Average Score: 0.21
# Episode 175	Average Score: 0.20Maxi 299
# Episode 175	Average Score: 0.20
# Episode 176	Average Score: 0.21Maxi 299
# Episode 176	Average Score: 0.21
# Episode 177	Average Score: 0.20Maxi 299
# Episode 177	Average Score: 0.20
# Episode 178	Average Score: 0.20Maxi 299
# Episode 178	Average Score: 0.20
# Episode 179	Average Score: 0.22Maxi 299
# Episode 179	Average Score: 0.22
# Episode 180	Average Score: 0.23Maxi 299
# Episode 180	Average Score: 0.23
# Episode 181	Average Score: 0.19Maxi 299
# Episode 181	Average Score: 0.19
# Episode 182	Average Score: 0.18Maxi 299
# Episode 182	Average Score: 0.18
# Episode 183	Average Score: 0.18Maxi 299
# Episode 183	Average Score: 0.18
# Episode 184	Average Score: 0.17Maxi 299
# Episode 184	Average Score: 0.17
# Episode 185	Average Score: 0.18Maxi 299
# Episode 185	Average Score: 0.18
# Episode 186	Average Score: 0.20Maxi 299
# Episode 186	Average Score: 0.20
# Episode 187	Average Score: 0.19Maxi 299
# Episode 187	Average Score: 0.19
# Episode 188	Average Score: 0.19Maxi 299
# Episode 188	Average Score: 0.19
# Episode 189	Average Score: 0.21Maxi 299
# Episode 189	Average Score: 0.21
# Episode 190	Average Score: 0.23Maxi 299
# Episode 190	Average Score: 0.23
# Episode 191	Average Score: 0.22Maxi 299
# Episode 191	Average Score: 0.22
# Episode 192	Average Score: 0.25Maxi 299
# Episode 192	Average Score: 0.25
# Episode 193	Average Score: 0.25Maxi 299
# Episode 193	Average Score: 0.25
# Episode 194	Average Score: 0.24Maxi 299
# Episode 194	Average Score: 0.24
# Episode 195	Average Score: 0.23Maxi 299
# Episode 195	Average Score: 0.23
# Episode 196	Average Score: 0.28Maxi 299
# Episode 196	Average Score: 0.28
# Episode 197	Average Score: 0.27Maxi 299
# Episode 197	Average Score: 0.27
# Episode 198	Average Score: 0.27Maxi 299
# Episode 198	Average Score: 0.27
# Episode 199	Average Score: 0.27Maxi 299
# Episode 199	Average Score: 0.27
# Episode 200	Average Score: 0.29Maxi 299
# Episode 200	Average Score: 0.29
# Episode 201	Average Score: 0.29Maxi 299
# Episode 201	Average Score: 0.29
# Episode 202	Average Score: 0.29Maxi 299
# Episode 202	Average Score: 0.29
# Episode 203	Average Score: 0.30Maxi 299
# Episode 203	Average Score: 0.30
# Episode 204	Average Score: 0.30Maxi 299
# Episode 204	Average Score: 0.30
# Episode 205	Average Score: 0.33Maxi 299
# Episode 205	Average Score: 0.33
# Episode 206	Average Score: 0.30Maxi 299
# Episode 206	Average Score: 0.30
# Episode 207	Average Score: 0.34Maxi 299
# Episode 207	Average Score: 0.34
# Episode 208	Average Score: 0.35Maxi 299
# Episode 208	Average Score: 0.35
# Episode 209	Average Score: 0.38Maxi 299
# Episode 209	Average Score: 0.38
# Episode 210	Average Score: 0.39Maxi 299
# Episode 210	Average Score: 0.39
# Episode 211	Average Score: 0.40Maxi 299
# Episode 211	Average Score: 0.40
# Episode 212	Average Score: 0.40Maxi 299
# Episode 212	Average Score: 0.40
# Episode 213	Average Score: 0.42Maxi 299
# Episode 213	Average Score: 0.42
# Episode 214	Average Score: 0.42Maxi 299
# Episode 214	Average Score: 0.42
# Episode 215	Average Score: 0.38Maxi 299
# Episode 215	Average Score: 0.38
# Episode 216	Average Score: 0.42Maxi 299
# Episode 216	Average Score: 0.42
# Episode 217	Average Score: 0.42Maxi 299
# Episode 217	Average Score: 0.42
# Episode 218	Average Score: 0.42Maxi 299
# Episode 218	Average Score: 0.42
# Episode 219	Average Score: 0.41Maxi 299
# Episode 219	Average Score: 0.41
# Episode 220	Average Score: 0.40Maxi 299
# Episode 220	Average Score: 0.40
# Episode 221	Average Score: 0.39Maxi 299
# Episode 221	Average Score: 0.39
# Episode 222	Average Score: 0.40Maxi 299
# Episode 222	Average Score: 0.40
# Episode 223	Average Score: 0.41Maxi 299
# Episode 223	Average Score: 0.41
# Episode 224	Average Score: 0.44Maxi 299
# Episode 224	Average Score: 0.44
# Episode 225	Average Score: 0.48Maxi 299
# Episode 225	Average Score: 0.48
# Episode 226	Average Score: 0.49Maxi 299
# Episode 226	Average Score: 0.49
# Episode 227	Average Score: 0.48Maxi 299
# Episode 227	Average Score: 0.48
# Episode 228	Average Score: 0.49Maxi 299
# Episode 228	Average Score: 0.49
# Episode 229	Average Score: 0.48Maxi 299
# Episode 229	Average Score: 0.48
# Episode 230	Average Score: 0.49Maxi 299
# Episode 230	Average Score: 0.49
# Episode 231	Average Score: 0.47Maxi 299
# Episode 231	Average Score: 0.47
# Episode 232	Average Score: 0.46Maxi 299
# Episode 232	Average Score: 0.46
# Episode 233	Average Score: 0.45Maxi 299
# Episode 233	Average Score: 0.45
# Episode 234	Average Score: 0.44Maxi 299
# Episode 234	Average Score: 0.44
# Episode 235	Average Score: 0.41Maxi 299
# Episode 235	Average Score: 0.41
# Episode 236	Average Score: 0.45Maxi 299
# Episode 236	Average Score: 0.45
# Episode 237	Average Score: 0.43Maxi 299
# Episode 237	Average Score: 0.43
# Episode 238	Average Score: 0.44Maxi 299
# Episode 238	Average Score: 0.44
# Episode 239	Average Score: 0.45Maxi 299
# Episode 239	Average Score: 0.45
# Episode 240	Average Score: 0.44Maxi 299
# Episode 240	Average Score: 0.44
# Episode 241	Average Score: 0.46Maxi 299
# Episode 241	Average Score: 0.46
# Episode 242	Average Score: 0.45Maxi 299
# Episode 242	Average Score: 0.45
# Episode 243	Average Score: 0.46Maxi 299
# Episode 243	Average Score: 0.46
# Episode 244	Average Score: 0.44Maxi 299
# Episode 244	Average Score: 0.44
# Episode 245	Average Score: 0.45Maxi 299
# Episode 245	Average Score: 0.45
# Episode 246	Average Score: 0.47Maxi 299
# Episode 246	Average Score: 0.47
# Episode 247	Average Score: 0.50Maxi 299
# Episode 247	Average Score: 0.50
# Episode 248	Average Score: 0.52Maxi 299
# Episode 248	Average Score: 0.52
# Episode 249	Average Score: 0.51Maxi 299
# Episode 249	Average Score: 0.51
# Episode 250	Average Score: 0.53Maxi 299
# Episode 250	Average Score: 0.53
# Episode 251	Average Score: 0.51Maxi 299
# Episode 251	Average Score: 0.51
# Episode 252	Average Score: 0.52Maxi 299
# Episode 252	Average Score: 0.52
# Episode 253	Average Score: 0.51Maxi 299
# Episode 253	Average Score: 0.51
# Episode 254	Average Score: 0.52Maxi 299
# Episode 254	Average Score: 0.52
# Episode 255	Average Score: 0.56Maxi 299
# Episode 255	Average Score: 0.56
# Episode 256	Average Score: 0.57Maxi 299
# Episode 256	Average Score: 0.57
# Episode 257	Average Score: 0.57Maxi 299
# Episode 257	Average Score: 0.57
# Episode 258	Average Score: 0.57Maxi 299
# Episode 258	Average Score: 0.57
# Episode 259	Average Score: 0.56Maxi 299
# Episode 259	Average Score: 0.56
# Episode 260	Average Score: 0.54Maxi 299
# Episode 260	Average Score: 0.54
# Episode 261	Average Score: 0.52Maxi 299
# Episode 261	Average Score: 0.52
# Episode 262	Average Score: 0.52Maxi 299
# Episode 262	Average Score: 0.52
# Episode 263	Average Score: 0.52Maxi 299
# Episode 263	Average Score: 0.52
# Episode 264	Average Score: 0.51Maxi 299
# Episode 264	Average Score: 0.51
# Episode 265	Average Score: 0.50Maxi 299
# Episode 265	Average Score: 0.50
# Episode 266	Average Score: 0.46Maxi 299
# Episode 266	Average Score: 0.46
# Episode 267	Average Score: 0.47Maxi 299
# Episode 267	Average Score: 0.47
# Episode 268	Average Score: 0.52Maxi 299
# Episode 268	Average Score: 0.52
# Episode 269	Average Score: 0.53Maxi 299
# Episode 269	Average Score: 0.53
# Episode 270	Average Score: 0.48Maxi 299
# Episode 270	Average Score: 0.48
# Episode 271	Average Score: 0.47Maxi 299
# Episode 271	Average Score: 0.47
# Episode 272	Average Score: 0.46Maxi 299
# Episode 272	Average Score: 0.46
# Episode 273	Average Score: 0.47Maxi 299
# Episode 273	Average Score: 0.47
# Episode 274	Average Score: 0.48Maxi 299
# Episode 274	Average Score: 0.48
# Episode 275	Average Score: 0.50Maxi 299
# Episode 275	Average Score: 0.50
# Episode 276	Average Score: 0.52Maxi 299
# Episode 276	Average Score: 0.52
# Episode 277	Average Score: 0.52Maxi 299
# Episode 277	Average Score: 0.52
# Episode 278	Average Score: 0.52Maxi 299
# Episode 278	Average Score: 0.52
# Episode 279	Average Score: 0.51Maxi 299
# Episode 279	Average Score: 0.51
# Episode 280	Average Score: 0.50Maxi 299
# Episode 280	Average Score: 0.50
# Episode 281	Average Score: 0.51Maxi 299
# Episode 281	Average Score: 0.51
# Episode 282	Average Score: 0.51Maxi 299
# Episode 282	Average Score: 0.51
# Episode 283	Average Score: 0.49Maxi 299
# Episode 283	Average Score: 0.49
# Episode 284	Average Score: 0.50Maxi 299
# Episode 284	Average Score: 0.50
# Episode 285	Average Score: 0.51Maxi 299
# Episode 285	Average Score: 0.51
# Episode 286	Average Score: 0.51Maxi 299
# Episode 286	Average Score: 0.51
# Episode 287	Average Score: 0.52Maxi 299
# Episode 287	Average Score: 0.52
# Episode 288	Average Score: 0.52Maxi 299
# Episode 288	Average Score: 0.52
# Episode 289	Average Score: 0.54Maxi 299
# Episode 289	Average Score: 0.54
# Episode 290	Average Score: 0.52Maxi 299
# Episode 290	Average Score: 0.52
# Episode 291	Average Score: 0.54Maxi 299
# Episode 291	Average Score: 0.54
# Episode 292	Average Score: 0.53Maxi 299
# Episode 292	Average Score: 0.53
# Episode 293	Average Score: 0.56Maxi 299
# Episode 293	Average Score: 0.56
# Episode 294	Average Score: 0.62Maxi 299
# Episode 294	Average Score: 0.62
# Episode 295	Average Score: 0.64Maxi 299
# Episode 295	Average Score: 0.64
# Episode 296	Average Score: 0.61Maxi 299
# Episode 296	Average Score: 0.61
# Episode 297	Average Score: 0.61Maxi 299
# Episode 297	Average Score: 0.61
# Episode 298	Average Score: 0.62Maxi 299
# Episode 298	Average Score: 0.62
# Episode 299	Average Score: 0.64Maxi 299
# Episode 299	Average Score: 0.64
# Episode 300	Average Score: 0.63Maxi 299
# Episode 300	Average Score: 0.63
# Episode 301	Average Score: 0.63Maxi 299
# Episode 301	Average Score: 0.63
# Episode 302	Average Score: 0.64Maxi 299
# Episode 302	Average Score: 0.64
# Episode 303	Average Score: 0.62Maxi 299
# Episode 303	Average Score: 0.62
# Episode 304	Average Score: 0.61Maxi 299
# Episode 304	Average Score: 0.61
# Episode 305	Average Score: 0.59Maxi 299
# Episode 305	Average Score: 0.59
# Episode 306	Average Score: 0.65Maxi 299
# Episode 306	Average Score: 0.65
# Episode 307	Average Score: 0.60Maxi 299
# Episode 307	Average Score: 0.60
# Episode 308	Average Score: 0.60Maxi 299
# Episode 308	Average Score: 0.60
# Episode 309	Average Score: 0.60Maxi 299
# Episode 309	Average Score: 0.60
# Episode 310	Average Score: 0.61Maxi 299
# Episode 310	Average Score: 0.61
# Episode 311	Average Score: 0.58Maxi 299
# Episode 311	Average Score: 0.58
# Episode 312	Average Score: 0.58Maxi 299
# Episode 312	Average Score: 0.58
# Episode 313	Average Score: 0.57Maxi 299
# Episode 313	Average Score: 0.57
# Episode 314	Average Score: 0.56Maxi 299
# Episode 314	Average Score: 0.56
# Episode 315	Average Score: 0.59Maxi 299
# Episode 315	Average Score: 0.59
# Episode 316	Average Score: 0.54Maxi 299
# Episode 316	Average Score: 0.54
# Episode 317	Average Score: 0.54Maxi 299
# Episode 317	Average Score: 0.54
# Episode 318	Average Score: 0.55Maxi 299
# Episode 318	Average Score: 0.55
# Episode 319	Average Score: 0.56Maxi 299
# Episode 319	Average Score: 0.56
# Episode 320	Average Score: 0.57Maxi 299
# Episode 320	Average Score: 0.57
# Episode 321	Average Score: 0.58Maxi 299
# Episode 321	Average Score: 0.58
# Episode 322	Average Score: 0.60Maxi 299
# Episode 322	Average Score: 0.60
# Episode 323	Average Score: 0.59Maxi 299
# Episode 323	Average Score: 0.59
# Episode 324	Average Score: 0.59Maxi 299
# Episode 324	Average Score: 0.59
# Episode 325	Average Score: 0.57Maxi 299
# Episode 325	Average Score: 0.57
# Episode 326	Average Score: 0.55Maxi 299
# Episode 326	Average Score: 0.55
# Episode 327	Average Score: 0.56Maxi 299
# Episode 327	Average Score: 0.56
# Episode 328	Average Score: 0.55Maxi 299
# Episode 328	Average Score: 0.55
# Episode 329	Average Score: 0.53Maxi 299
# Episode 329	Average Score: 0.53
# Episode 330	Average Score: 0.52Maxi 299
# Episode 330	Average Score: 0.52
# Episode 331	Average Score: 0.52Maxi 299
# Episode 331	Average Score: 0.52
# Episode 332	Average Score: 0.50Maxi 299
# Episode 332	Average Score: 0.50
# Episode 333	Average Score: 0.49Maxi 299
# Episode 333	Average Score: 0.49
# Episode 334	Average Score: 0.51Maxi 299
# Episode 334	Average Score: 0.51
# Episode 335	Average Score: 0.52Maxi 299
# Episode 335	Average Score: 0.52
# Episode 336	Average Score: 0.48Maxi 299
# Episode 336	Average Score: 0.48
# Episode 337	Average Score: 0.49Maxi 299
# Episode 337	Average Score: 0.49
# Episode 338	Average Score: 0.45Maxi 299
# Episode 338	Average Score: 0.45
# Episode 339	Average Score: 0.44Maxi 299
# Episode 339	Average Score: 0.44
# Episode 340	Average Score: 0.46Maxi 299
# Episode 340	Average Score: 0.46
# Episode 341	Average Score: 0.43Maxi 299
# Episode 341	Average Score: 0.43
# Episode 342	Average Score: 0.46Maxi 299
# Episode 342	Average Score: 0.46
# Episode 343	Average Score: 0.43Maxi 299
# Episode 343	Average Score: 0.43
# Episode 344	Average Score: 0.45Maxi 299
# Episode 344	Average Score: 0.45
# Episode 345	Average Score: 0.43Maxi 299
# Episode 345	Average Score: 0.43
# Episode 346	Average Score: 0.42Maxi 299
# Episode 346	Average Score: 0.42
# Episode 347	Average Score: 0.40Maxi 299
# Episode 347	Average Score: 0.40
# Episode 348	Average Score: 0.38Maxi 299
# Episode 348	Average Score: 0.38
# Episode 349	Average Score: 0.38Maxi 299
# Episode 349	Average Score: 0.38
# Episode 350	Average Score: 0.37Maxi 299
# Episode 350	Average Score: 0.37
# Episode 351	Average Score: 0.40Maxi 299
# Episode 351	Average Score: 0.40
# Episode 352	Average Score: 0.38Maxi 299
# Episode 352	Average Score: 0.38
# Episode 353	Average Score: 0.40Maxi 299
# Episode 353	Average Score: 0.40
# Episode 354	Average Score: 0.41Maxi 299
# Episode 354	Average Score: 0.41
# Episode 355	Average Score: 0.41Maxi 299
# Episode 355	Average Score: 0.41
# Episode 356	Average Score: 0.41Maxi 299
# Episode 356	Average Score: 0.41
# Episode 357	Average Score: 0.40Maxi 299
# Episode 357	Average Score: 0.40
# Episode 358	Average Score: 0.41Maxi 299
# Episode 358	Average Score: 0.41
# Episode 359	Average Score: 0.41Maxi 299
# Episode 359	Average Score: 0.41
# Episode 360	Average Score: 0.42Maxi 299
# Episode 360	Average Score: 0.42
# Episode 361	Average Score: 0.47Maxi 299
# Episode 361	Average Score: 0.47
# Episode 362	Average Score: 0.46Maxi 299
# Episode 362	Average Score: 0.46
# Episode 363	Average Score: 0.43Maxi 299
# Episode 363	Average Score: 0.43
# Episode 364	Average Score: 0.42Maxi 299
# Episode 364	Average Score: 0.42
# Episode 365	Average Score: 0.39Maxi 299
# Episode 365	Average Score: 0.39
# Episode 366	Average Score: 0.42Maxi 299
# Episode 366	Average Score: 0.42
# Episode 367	Average Score: 0.42Maxi 299
# Episode 367	Average Score: 0.42
# Episode 368	Average Score: 0.37Maxi 299
# Episode 368	Average Score: 0.37
# Episode 369	Average Score: 0.34Maxi 299
# Episode 369	Average Score: 0.34
# Episode 370	Average Score: 0.35Maxi 299
# Episode 370	Average Score: 0.35
# Episode 371	Average Score: 0.39Maxi 299
# Episode 371	Average Score: 0.39
# Episode 372	Average Score: 0.42Maxi 299
# Episode 372	Average Score: 0.42
# Episode 373	Average Score: 0.43Maxi 299
# Episode 373	Average Score: 0.43
# Episode 374	Average Score: 0.45Maxi 299
# Episode 374	Average Score: 0.45
# Episode 375	Average Score: 0.44Maxi 299
# Episode 375	Average Score: 0.44
# Episode 376	Average Score: 0.42Maxi 299
# Episode 376	Average Score: 0.42
# Episode 377	Average Score: 0.41Maxi 299
# Episode 377	Average Score: 0.41
# Episode 378	Average Score: 0.40Maxi 299
# Episode 378	Average Score: 0.40
# Episode 379	Average Score: 0.41Maxi 299
# Episode 379	Average Score: 0.41
# Episode 380	Average Score: 0.41Maxi 299
# Episode 380	Average Score: 0.41
# Episode 381	Average Score: 0.43Maxi 299
# Episode 381	Average Score: 0.43
# Episode 382	Average Score: 0.42Maxi 299
# Episode 382	Average Score: 0.42
# Episode 383	Average Score: 0.42Maxi 299
# Episode 383	Average Score: 0.42
# Episode 384	Average Score: 0.42Maxi 299
# Episode 384	Average Score: 0.42
# Episode 385	Average Score: 0.40Maxi 299
# Episode 385	Average Score: 0.40
# Episode 386	Average Score: 0.40Maxi 299
# Episode 386	Average Score: 0.40
# Episode 387	Average Score: 0.40Maxi 299
# Episode 387	Average Score: 0.40
# Episode 388	Average Score: 0.41Maxi 299
# Episode 388	Average Score: 0.41
# Episode 389	Average Score: 0.37Maxi 299
# Episode 389	Average Score: 0.37
# Episode 390	Average Score: 0.39Maxi 299
# Episode 390	Average Score: 0.39
# Episode 391	Average Score: 0.36Maxi 299
# Episode 391	Average Score: 0.36
# Episode 392	Average Score: 0.36Maxi 299
# Episode 392	Average Score: 0.36
# Episode 393	Average Score: 0.35Maxi 299
# Episode 393	Average Score: 0.35
# Episode 394	Average Score: 0.33Maxi 299
# Episode 394	Average Score: 0.33
# Episode 395	Average Score: 0.32Maxi 299
# Episode 395	Average Score: 0.32
# Episode 396	Average Score: 0.32Maxi 299
# Episode 396	Average Score: 0.32
# Episode 397	Average Score: 0.31Maxi 299
# Episode 397	Average Score: 0.31
# Episode 398	Average Score: 0.33Maxi 299
# Episode 398	Average Score: 0.33
# Episode 399	Average Score: 0.33Maxi 299
# Episode 399	Average Score: 0.33
# Episode 400	Average Score: 0.36Maxi 299
# Episode 400	Average Score: 0.36
# Episode 401	Average Score: 0.34Maxi 299
# Episode 401	Average Score: 0.34
# Episode 402	Average Score: 0.33Maxi 299
# Episode 402	Average Score: 0.33
# Episode 403	Average Score: 0.34Maxi 299
# Episode 403	Average Score: 0.34
# Episode 404	Average Score: 0.36Maxi 299
# Episode 404	Average Score: 0.36
# Episode 405	Average Score: 0.39Maxi 299
# Episode 405	Average Score: 0.39
# Episode 406	Average Score: 0.36Maxi 299
# Episode 406	Average Score: 0.36
# Episode 407	Average Score: 0.33Maxi 299
# Episode 407	Average Score: 0.33
# Episode 408	Average Score: 0.29Maxi 299
# Episode 408	Average Score: 0.29
# Episode 409	Average Score: 0.28Maxi 299
# Episode 409	Average Score: 0.28
# Episode 410	Average Score: 0.26Maxi 299
# Episode 410	Average Score: 0.26
# Episode 411	Average Score: 0.29Maxi 299
# Episode 411	Average Score: 0.29
# Episode 412	Average Score: 0.27Maxi 299
# Episode 412	Average Score: 0.27
# Episode 413	Average Score: 0.28Maxi 299
# Episode 413	Average Score: 0.28
# Episode 414	Average Score: 0.32Maxi 299
# Episode 414	Average Score: 0.32
# Episode 415	Average Score: 0.33Maxi 299
# Episode 415	Average Score: 0.33
# Episode 416	Average Score: 0.36Maxi 299
# Episode 416	Average Score: 0.36
# Episode 417	Average Score: 0.35Maxi 299
# Episode 417	Average Score: 0.35
# Episode 418	Average Score: 0.35Maxi 299
# Episode 418	Average Score: 0.35
# Episode 419	Average Score: 0.36Maxi 299
# Episode 419	Average Score: 0.36
# Episode 420	Average Score: 0.35Maxi 299
# Episode 420	Average Score: 0.35
# Episode 421	Average Score: 0.35Maxi 299
# Episode 421	Average Score: 0.35
# Episode 422	Average Score: 0.34Maxi 299
# Episode 422	Average Score: 0.34
# Episode 423	Average Score: 0.35Maxi 299
# Episode 423	Average Score: 0.35
# Episode 424	Average Score: 0.35Maxi 299
# Episode 424	Average Score: 0.35
# Episode 425	Average Score: 0.37Maxi 299
# Episode 425	Average Score: 0.37
# Episode 426	Average Score: 0.38Maxi 299
# Episode 426	Average Score: 0.38
# Episode 427	Average Score: 0.37Maxi 299
# Episode 427	Average Score: 0.37
# Episode 428	Average Score: 0.38Maxi 299
# Episode 428	Average Score: 0.38
# Episode 429	Average Score: 0.40Maxi 299
# Episode 429	Average Score: 0.40
# Episode 430	Average Score: 0.42Maxi 299
# Episode 430	Average Score: 0.42
# Episode 431	Average Score: 0.43Maxi 299
# Episode 431	Average Score: 0.43
# Episode 432	Average Score: 0.44Maxi 299
# Episode 432	Average Score: 0.44
# Episode 433	Average Score: 0.42Maxi 299
# Episode 433	Average Score: 0.42
# Episode 434	Average Score: 0.43Maxi 299
# Episode 434	Average Score: 0.43
# Episode 435	Average Score: 0.46Maxi 299
# Episode 435	Average Score: 0.46
# Episode 436	Average Score: 0.46Maxi 299
# Episode 436	Average Score: 0.46
# Episode 437	Average Score: 0.47Maxi 299
# Episode 437	Average Score: 0.47
# Episode 438	Average Score: 0.51Maxi 299
# Episode 438	Average Score: 0.51
# Episode 439	Average Score: 0.51Maxi 299
# Episode 439	Average Score: 0.51
# Episode 440	Average Score: 0.48Maxi 299
# Episode 440	Average Score: 0.48
# Episode 441	Average Score: 0.49Maxi 299
# Episode 441	Average Score: 0.49
# Episode 442	Average Score: 0.48Maxi 299
# Episode 442	Average Score: 0.48
# Episode 443	Average Score: 0.50Maxi 299
# Episode 443	Average Score: 0.50
# Episode 444	Average Score: 0.50Maxi 299
# Episode 444	Average Score: 0.50
# Episode 445	Average Score: 0.50Maxi 299
# Episode 445	Average Score: 0.50
# Episode 446	Average Score: 0.51Maxi 299
# Episode 446	Average Score: 0.51
# Episode 447	Average Score: 0.49Maxi 299
# Episode 447	Average Score: 0.49
# Episode 448	Average Score: 0.49Maxi 299
# Episode 448	Average Score: 0.49
# Episode 449	Average Score: 0.49Maxi 299
# Episode 449	Average Score: 0.49
# Episode 450	Average Score: 0.50Maxi 299
# Episode 450	Average Score: 0.50
# Episode 451	Average Score: 0.49Maxi 299
# Episode 451	Average Score: 0.49
# Episode 452	Average Score: 0.48Maxi 299
# Episode 452	Average Score: 0.48
# Episode 453	Average Score: 0.49Maxi 299
# Episode 453	Average Score: 0.49
# Episode 454	Average Score: 0.47Maxi 299
# Episode 454	Average Score: 0.47
# Episode 455	Average Score: 0.45Maxi 299
# Episode 455	Average Score: 0.45
# Episode 456	Average Score: 0.46Maxi 299
# Episode 456	Average Score: 0.46
# Episode 457	Average Score: 0.49Maxi 299
# Episode 457	Average Score: 0.49
# Episode 458	Average Score: 0.49Maxi 299
# Episode 458	Average Score: 0.49
# Episode 459	Average Score: 0.49Maxi 299
# Episode 459	Average Score: 0.49
# Episode 460	Average Score: 0.50Maxi 299
# Episode 460	Average Score: 0.50
# Episode 461	Average Score: 0.50Maxi 299
# Episode 461	Average Score: 0.50
# Episode 462	Average Score: 0.52Maxi 299
# Episode 462	Average Score: 0.52
# Episode 463	Average Score: 0.56Maxi 299
# Episode 463	Average Score: 0.56
# Episode 464	Average Score: 0.56Maxi 299
# Episode 464	Average Score: 0.56
# Episode 465	Average Score: 0.59Maxi 299
# Episode 465	Average Score: 0.59
# Episode 466	Average Score: 0.58Maxi 299
# Episode 466	Average Score: 0.58
# Episode 467	Average Score: 0.60Maxi 299
# Episode 467	Average Score: 0.60
# Episode 468	Average Score: 0.63Maxi 299
# Episode 468	Average Score: 0.63
# Episode 469	Average Score: 0.65Maxi 299
# Episode 469	Average Score: 0.65
# Episode 470	Average Score: 0.67Maxi 299
# Episode 470	Average Score: 0.67
# Episode 471	Average Score: 0.66Maxi 299
# Episode 471	Average Score: 0.66
# Episode 472	Average Score: 0.64Maxi 299
# Episode 472	Average Score: 0.64
# Episode 473	Average Score: 0.65Maxi 299
# Episode 473	Average Score: 0.65
# Episode 474	Average Score: 0.65Maxi 299
# Episode 474	Average Score: 0.65
# Episode 475	Average Score: 0.68Maxi 299
# Episode 475	Average Score: 0.68
# Episode 476	Average Score: 0.69Maxi 299
# Episode 476	Average Score: 0.69
# Episode 477	Average Score: 0.73Maxi 299
# Episode 477	Average Score: 0.73
# Episode 478	Average Score: 0.77Maxi 299
# Episode 478	Average Score: 0.77
# Episode 479	Average Score: 0.77Maxi 299
# Episode 479	Average Score: 0.77
# Episode 480	Average Score: 0.79Maxi 299
# Episode 480	Average Score: 0.79
# Episode 481	Average Score: 0.79Maxi 299
# Episode 481	Average Score: 0.79
# Episode 482	Average Score: 0.82Maxi 299
# Episode 482	Average Score: 0.82
# Episode 483	Average Score: 0.82Maxi 299
# Episode 483	Average Score: 0.82
# Episode 484	Average Score: 0.85Maxi 299
# Episode 484	Average Score: 0.85
# Episode 485	Average Score: 0.85Maxi 299
# Episode 485	Average Score: 0.85
# Episode 486	Average Score: 0.86Maxi 299
# Episode 486	Average Score: 0.86
# Episode 487	Average Score: 0.85Maxi 299
# Episode 487	Average Score: 0.85
# Episode 488	Average Score: 0.85Maxi 299
# Episode 488	Average Score: 0.85
# Episode 489	Average Score: 0.88Maxi 299
# Episode 489	Average Score: 0.88
# Episode 490	Average Score: 0.87Maxi 299
# Episode 490	Average Score: 0.87
# Episode 491	Average Score: 0.91Maxi 299
# Episode 491	Average Score: 0.91
# Episode 492	Average Score: 0.90Maxi 299
# Episode 492	Average Score: 0.90
# Episode 493	Average Score: 0.89Maxi 299
# Episode 493	Average Score: 0.89
# Episode 494	Average Score: 0.89Maxi 299
# Episode 494	Average Score: 0.89
# Episode 495	Average Score: 0.88Maxi 299
# Episode 495	Average Score: 0.88
# Episode 496	Average Score: 0.90Maxi 299
# Episode 496	Average Score: 0.90
# Episode 497	Average Score: 0.89Maxi 299
# Episode 497	Average Score: 0.89
# Episode 498	Average Score: 0.90Maxi 299
# Episode 498	Average Score: 0.90
# Episode 499	Average Score: 0.90Maxi 299
# Episode 499	Average Score: 0.90
# Episode 500	Average Score: 0.86Maxi 299
# Episode 500	Average Score: 0.86
# Episode 501	Average Score: 0.90Maxi 299
# Episode 501	Average Score: 0.90
# Episode 502	Average Score: 0.92Maxi 299
# Episode 502	Average Score: 0.92
# Episode 503	Average Score: 0.91Maxi 299
# Episode 503	Average Score: 0.91
# Episode 504	Average Score: 0.94Maxi 299
# Episode 504	Average Score: 0.94
# Episode 505	Average Score: 0.91Maxi 299
# Episode 505	Average Score: 0.91
# Episode 506	Average Score: 0.91Maxi 299
# Episode 506	Average Score: 0.91
# Episode 507	Average Score: 0.97Maxi 299
# Episode 507	Average Score: 0.97
# Episode 508	Average Score: 1.04Maxi 299
# Episode 508	Average Score: 1.04
# Episode 509	Average Score: 1.10Maxi 299
# Episode 509	Average Score: 1.10
# Episode 510	Average Score: 1.10Maxi 299
# Episode 510	Average Score: 1.10
# Episode 511	Average Score: 1.07Maxi 299
# Episode 511	Average Score: 1.07
# Episode 512	Average Score: 1.10Maxi 299
# Episode 512	Average Score: 1.10
# Episode 513	Average Score: 1.10Maxi 299
# Episode 513	Average Score: 1.10
# Episode 514	Average Score: 1.10Maxi 299
# Episode 514	Average Score: 1.10
# Episode 515	Average Score: 1.12Maxi 299
# Episode 515	Average Score: 1.12
# Episode 516	Average Score: 1.15Maxi 299
# Episode 516	Average Score: 1.15
# Episode 517	Average Score: 1.17Maxi 299
# Episode 517	Average Score: 1.17
# Episode 518	Average Score: 1.17Maxi 299
# Episode 518	Average Score: 1.17
# Episode 519	Average Score: 1.16Maxi 299
# Episode 519	Average Score: 1.16
# Episode 520	Average Score: 1.22Maxi 299
# Episode 520	Average Score: 1.22
# Episode 521	Average Score: 1.24Maxi 299
# Episode 521	Average Score: 1.24
# Episode 522	Average Score: 1.24Maxi 299
# Episode 522	Average Score: 1.24
# Episode 523	Average Score: 1.25Maxi 299
# Episode 523	Average Score: 1.25
# Episode 524	Average Score: 1.24Maxi 299
# Episode 524	Average Score: 1.24
# Episode 525	Average Score: 1.25Maxi 299
# Episode 525	Average Score: 1.25
# Episode 526	Average Score: 1.27Maxi 299
# Episode 526	Average Score: 1.27
# Episode 527	Average Score: 1.30Maxi 299
# Episode 527	Average Score: 1.30
# Episode 528	Average Score: 1.30Maxi 299
# Episode 528	Average Score: 1.30
# Episode 529	Average Score: 1.30Maxi 299
# Episode 529	Average Score: 1.30
# Episode 530	Average Score: 1.26Maxi 299
# Episode 530	Average Score: 1.26
# Episode 531	Average Score: 1.27Maxi 299
# Episode 531	Average Score: 1.27
# Episode 532	Average Score: 1.30Maxi 299
# Episode 532	Average Score: 1.30
# Episode 533	Average Score: 1.33Maxi 299
# Episode 533	Average Score: 1.33
# Episode 534	Average Score: 1.34Maxi 299
# Episode 534	Average Score: 1.34
# Episode 535	Average Score: 1.32Maxi 299
# Episode 535	Average Score: 1.32
# Episode 536	Average Score: 1.30Maxi 299
# Episode 536	Average Score: 1.30
# Episode 537	Average Score: 1.29Maxi 299
# Episode 537	Average Score: 1.29
# Episode 538	Average Score: 1.29Maxi 299
# Episode 538	Average Score: 1.29
# Episode 539	Average Score: 1.32Maxi 299
# Episode 539	Average Score: 1.32
# Episode 540	Average Score: 1.35Maxi 299
# Episode 540	Average Score: 1.35
# Episode 541	Average Score: 1.36Maxi 299
# Episode 541	Average Score: 1.36
# Episode 542	Average Score: 1.41Maxi 299
# Episode 542	Average Score: 1.41
# Episode 543	Average Score: 1.42Maxi 299
# Episode 543	Average Score: 1.42
# Episode 544	Average Score: 1.41Maxi 299
# Episode 544	Average Score: 1.41
# Episode 545	Average Score: 1.41Maxi 299
# Episode 545	Average Score: 1.41
# Episode 546	Average Score: 1.39Maxi 299
# Episode 546	Average Score: 1.39
# Episode 547	Average Score: 1.43Maxi 299
# Episode 547	Average Score: 1.43
# Episode 548	Average Score: 1.50Maxi 299
# Episode 548	Average Score: 1.50
# Episode 549	Average Score: 1.54Maxi 299
# Episode 549	Average Score: 1.54
# Episode 550	Average Score: 1.54Maxi 299
# Episode 550	Average Score: 1.54
# Episode 551	Average Score: 1.54Maxi 299
# Episode 551	Average Score: 1.54
# Episode 552	Average Score: 1.57Maxi 299
# Episode 552	Average Score: 1.57
# Episode 553	Average Score: 1.61Maxi 299
# Episode 553	Average Score: 1.61
# Episode 554	Average Score: 1.64Maxi 299
# Episode 554	Average Score: 1.64
# Episode 555	Average Score: 1.63Maxi 299
# Episode 555	Average Score: 1.63
# Episode 556	Average Score: 1.63Maxi 299
# Episode 556	Average Score: 1.63
# Episode 557	Average Score: 1.66Maxi 299
# Episode 557	Average Score: 1.66
# Episode 558	Average Score: 1.67Maxi 299
# Episode 558	Average Score: 1.67
# Episode 559	Average Score: 1.71Maxi 299
# Episode 559	Average Score: 1.71
# Episode 560	Average Score: 1.75Maxi 299
# Episode 560	Average Score: 1.75
# Episode 561	Average Score: 1.76Maxi 299
# Episode 561	Average Score: 1.76
# Episode 562	Average Score: 1.72Maxi 299
# Episode 562	Average Score: 1.72
# Episode 563	Average Score: 1.70Maxi 299
# Episode 563	Average Score: 1.70
# Episode 564	Average Score: 1.78Maxi 299
# Episode 564	Average Score: 1.78
# Episode 565	Average Score: 1.78Maxi 299
# Episode 565	Average Score: 1.78
# Episode 566	Average Score: 1.81Maxi 299
# Episode 566	Average Score: 1.81
# Episode 567	Average Score: 1.82Maxi 299
# Episode 567	Average Score: 1.82
# Episode 568	Average Score: 1.80Maxi 299
# Episode 568	Average Score: 1.80
# Episode 569	Average Score: 1.76Maxi 299
# Episode 569	Average Score: 1.76
# Episode 570	Average Score: 1.78Maxi 299
# Episode 570	Average Score: 1.78
# Episode 571	Average Score: 1.79Maxi 299
# Episode 571	Average Score: 1.79
# Episode 572	Average Score: 1.83Maxi 299
# Episode 572	Average Score: 1.83
# Episode 573	Average Score: 1.81Maxi 299
# Episode 573	Average Score: 1.81
# Episode 574	Average Score: 1.82Maxi 299
# Episode 574	Average Score: 1.82
# Episode 575	Average Score: 1.79Maxi 299
# Episode 575	Average Score: 1.79
# Episode 576	Average Score: 1.81Maxi 299
# Episode 576	Average Score: 1.81
# Episode 577	Average Score: 1.79Maxi 299
# Episode 577	Average Score: 1.79
# Episode 578	Average Score: 1.80Maxi 299
# Episode 578	Average Score: 1.80
# Episode 579	Average Score: 1.78Maxi 299
# Episode 579	Average Score: 1.78
# Episode 580	Average Score: 1.80Maxi 299
# Episode 580	Average Score: 1.80
# Episode 581	Average Score: 1.80Maxi 299
# Episode 581	Average Score: 1.80
# Episode 582	Average Score: 1.78Maxi 299
# Episode 582	Average Score: 1.78
# Episode 583	Average Score: 1.77Maxi 299
# Episode 583	Average Score: 1.77
# Episode 584	Average Score: 1.76Maxi 299
# Episode 584	Average Score: 1.76
# Episode 585	Average Score: 1.77Maxi 299
# Episode 585	Average Score: 1.77
# Episode 586	Average Score: 1.75Maxi 299
# Episode 586	Average Score: 1.75
# Episode 587	Average Score: 1.76Maxi 299
# Episode 587	Average Score: 1.76
# Episode 588	Average Score: 1.80Maxi 299
# Episode 588	Average Score: 1.80
# Episode 589	Average Score: 1.81Maxi 299
# Episode 589	Average Score: 1.81
# Episode 590	Average Score: 1.83Maxi 299
# Episode 590	Average Score: 1.83
# Episode 591	Average Score: 1.83Maxi 299
# Episode 591	Average Score: 1.83
# Episode 592	Average Score: 1.86Maxi 299
# Episode 592	Average Score: 1.86
# Episode 593	Average Score: 1.89Maxi 299
# Episode 593	Average Score: 1.89
# Episode 594	Average Score: 1.86Maxi 299
# Episode 594	Average Score: 1.86
# Episode 595	Average Score: 1.92Maxi 299
# Episode 595	Average Score: 1.92
# Episode 596	Average Score: 1.92Maxi 299
# Episode 596	Average Score: 1.92
# Episode 597	Average Score: 1.96Maxi 299
# Episode 597	Average Score: 1.96
# Episode 598	Average Score: 1.96Maxi 299
# Episode 598	Average Score: 1.96
# Episode 599	Average Score: 1.98Maxi 299
# Episode 599	Average Score: 1.98
# Episode 600	Average Score: 2.03Maxi 299
# Episode 600	Average Score: 2.03
# Episode 601	Average Score: 2.01Maxi 299
# Episode 601	Average Score: 2.01
# Episode 602	Average Score: 2.01Maxi 299
# Episode 602	Average Score: 2.01
# Episode 603	Average Score: 2.03Maxi 299
# Episode 603	Average Score: 2.03
# Episode 604	Average Score: 1.99Maxi 299
# Episode 604	Average Score: 1.99
# Episode 605	Average Score: 2.03Maxi 299
# Episode 605	Average Score: 2.03
# Episode 606	Average Score: 2.07Maxi 299
# Episode 606	Average Score: 2.07
# Episode 607	Average Score: 2.10Maxi 299
# Episode 607	Average Score: 2.10
# Episode 608	Average Score: 2.07Maxi 299
# Episode 608	Average Score: 2.07
# Episode 609	Average Score: 2.03Maxi 299
# Episode 609	Average Score: 2.03
# Episode 610	Average Score: 2.06Maxi 299
# Episode 610	Average Score: 2.06
# Episode 611	Average Score: 2.12Maxi 299
# Episode 611	Average Score: 2.12
# Episode 612	Average Score: 2.10Maxi 299
# Episode 612	Average Score: 2.10
# Episode 613	Average Score: 2.12Maxi 299
# Episode 613	Average Score: 2.12
# Episode 614	Average Score: 2.12Maxi 299
# Episode 614	Average Score: 2.12
# Episode 615	Average Score: 2.09Maxi 299
# Episode 615	Average Score: 2.09
# Episode 616	Average Score: 2.06Maxi 299
# Episode 616	Average Score: 2.06
# Episode 617	Average Score: 2.06Maxi 299
# Episode 617	Average Score: 2.06
# Episode 618	Average Score: 2.06Maxi 299
# Episode 618	Average Score: 2.06
# Episode 619	Average Score: 2.05Maxi 299
# Episode 619	Average Score: 2.05
# Episode 620	Average Score: 1.99Maxi 299
# Episode 620	Average Score: 1.99
# Episode 621	Average Score: 2.02Maxi 299
# Episode 621	Average Score: 2.02
# Episode 622	Average Score: 2.02Maxi 299
# Episode 622	Average Score: 2.02
# Episode 623	Average Score: 2.01Maxi 299
# Episode 623	Average Score: 2.01
# Episode 624	Average Score: 2.07Maxi 299
# Episode 624	Average Score: 2.07
# Episode 625	Average Score: 2.06Maxi 299
# Episode 625	Average Score: 2.06
# Episode 626	Average Score: 2.06Maxi 299
# Episode 626	Average Score: 2.06
# Episode 627	Average Score: 2.05Maxi 299
# Episode 627	Average Score: 2.05
# Episode 628	Average Score: 2.04Maxi 299
# Episode 628	Average Score: 2.04
# Episode 629	Average Score: 2.01Maxi 299
# Episode 629	Average Score: 2.01
# Episode 630	Average Score: 2.04Maxi 299
# Episode 630	Average Score: 2.04
# Episode 631	Average Score: 2.06Maxi 299
# Episode 631	Average Score: 2.06
# Episode 632	Average Score: 2.07Maxi 299
# Episode 632	Average Score: 2.07
# Episode 633	Average Score: 2.10Maxi 299
# Episode 633	Average Score: 2.10
# Episode 634	Average Score: 2.07Maxi 299
# Episode 634	Average Score: 2.07
# Episode 635	Average Score: 2.08Maxi 299
# Episode 635	Average Score: 2.08
# Episode 636	Average Score: 2.13Maxi 299
# Episode 636	Average Score: 2.13
# Episode 637	Average Score: 2.15Maxi 299
# Episode 637	Average Score: 2.15
# Episode 638	Average Score: 2.17Maxi 299
# Episode 638	Average Score: 2.17
# Episode 639	Average Score: 2.15Maxi 299
# Episode 639	Average Score: 2.15
# Episode 640	Average Score: 2.15Maxi 299
# Episode 640	Average Score: 2.15
# Episode 641	Average Score: 2.17Maxi 299
# Episode 641	Average Score: 2.17
# Episode 642	Average Score: 2.13Maxi 299
# Episode 642	Average Score: 2.13
# Episode 643	Average Score: 2.14Maxi 299
# Episode 643	Average Score: 2.14
# Episode 644	Average Score: 2.18Maxi 299
# Episode 644	Average Score: 2.18
# Episode 645	Average Score: 2.18Maxi 299
# Episode 645	Average Score: 2.18
# Episode 646	Average Score: 2.20Maxi 299
# Episode 646	Average Score: 2.20
# Episode 647	Average Score: 2.22Maxi 299
# Episode 647	Average Score: 2.22
# Episode 648	Average Score: 2.18Maxi 299
# Episode 648	Average Score: 2.18
# Episode 649	Average Score: 2.18Maxi 299
# Episode 649	Average Score: 2.18
# Episode 650	Average Score: 2.23Maxi 299
# Episode 650	Average Score: 2.23
# Episode 651	Average Score: 2.29Maxi 299
# Episode 651	Average Score: 2.29
# Episode 652	Average Score: 2.29Maxi 299
# Episode 652	Average Score: 2.29
# Episode 653	Average Score: 2.23Maxi 299
# Episode 653	Average Score: 2.23
# Episode 654	Average Score: 2.21Maxi 299
# Episode 654	Average Score: 2.21
# Episode 655	Average Score: 2.23Maxi 299
# Episode 655	Average Score: 2.23
# Episode 656	Average Score: 2.21Maxi 299
# Episode 656	Average Score: 2.21
# Episode 657	Average Score: 2.20Maxi 299
# Episode 657	Average Score: 2.20
# Episode 658	Average Score: 2.19Maxi 299
# Episode 658	Average Score: 2.19
# Episode 659	Average Score: 2.15Maxi 299
# Episode 659	Average Score: 2.15
# Episode 660	Average Score: 2.11Maxi 299
# Episode 660	Average Score: 2.11
# Episode 661	Average Score: 2.09Maxi 299
# Episode 661	Average Score: 2.09
# Episode 662	Average Score: 2.14Maxi 299
# Episode 662	Average Score: 2.14
# Episode 663	Average Score: 2.15Maxi 299
# Episode 663	Average Score: 2.15
# Episode 664	Average Score: 2.13Maxi 299
# Episode 664	Average Score: 2.13
# Episode 665	Average Score: 2.13Maxi 299
# Episode 665	Average Score: 2.13
# Episode 666	Average Score: 2.14Maxi 299
# Episode 666	Average Score: 2.14
# Episode 667	Average Score: 2.13Maxi 299
# Episode 667	Average Score: 2.13
# Episode 668	Average Score: 2.16Maxi 299
# Episode 668	Average Score: 2.16
# Episode 669	Average Score: 2.21Maxi 299
# ...
# Episode 1980	Average Score: 7.71Maxi 299
# Episode 1980	Average Score: 7.71
# Episode 1981	Average Score: 7.82Maxi 299
# Episode 1981	Average Score: 7.82
# Episode 1982	Average Score: 7.81Maxi 299
# Episode 1982	Average Score: 7.81
# Episode 1983	Average Score: 7.88Maxi 299
# Episode 1983	Average Score: 7.88
# Episode 1984	Average Score: 7.88Maxi 299
# Episode 1984	Average Score: 7.88
# Episode 1985	Average Score: 7.88Maxi 299
# Episode 1985	Average Score: 7.88
# Episode 1986	Average Score: 7.88Maxi 299
# Episode 1986	Average Score: 7.88
# Episode 1987	Average Score: 7.88Maxi 299
# Episode 1987	Average Score: 7.88
# Episode 1988	Average Score: 7.84Maxi 299
# Episode 1988	Average Score: 7.84
# Episode 1989	Average Score: 7.80Maxi 299
# Episode 1989	Average Score: 7.80
# Episode 1990	Average Score: 7.88Maxi 299
# Episode 1990	Average Score: 7.88
# Episode 1991	Average Score: 7.90Maxi 299
# Episode 1991	Average Score: 7.90
# Episode 1992	Average Score: 7.89Maxi 299
# Episode 1992	Average Score: 7.89
# Episode 1993	Average Score: 7.88Maxi 299
# Episode 1993	Average Score: 7.88
# Episode 1994	Average Score: 7.82Maxi 299
# Episode 1994	Average Score: 7.82
# Episode 1995	Average Score: 7.81Maxi 299
# Episode 1995	Average Score: 7.81
# Episode 1996	Average Score: 7.79Maxi 299
# Episode 1996	Average Score: 7.79
# Episode 1997	Average Score: 7.83Maxi 299
# Episode 1997	Average Score: 7.83
# Episode 1998	Average Score: 7.86Maxi 299
# Episode 1998	Average Score: 7.86
# Episode 1999	Average Score: 7.87Maxi 299
# Episode 1999	Average Score: 7.87
# Episode 2000	Average Score: 7.78Maxi 299
# Episode 2000	Average Score: 7.78
# Episode 2001	Average Score: 7.80Maxi 299
# Episode 2001	Average Score: 7.80
# Episode 2002	Average Score: 7.81Maxi 299
# Episode 2002	Average Score: 7.81
# Episode 2003	Average Score: 7.78Maxi 299
# Episode 2003	Average Score: 7.78
# Episode 2004	Average Score: 7.75Maxi 299
# Episode 2004	Average Score: 7.75
# Episode 2005	Average Score: 7.74Maxi 299
# Episode 2005	Average Score: 7.74
# Episode 2006	Average Score: 7.70Maxi 299
# Episode 2006	Average Score: 7.70
# Episode 2007	Average Score: 7.74Maxi 299
# Episode 2007	Average Score: 7.74
# Episode 2008	Average Score: 7.70Maxi 299
# Episode 2008	Average Score: 7.70
# Episode 2009	Average Score: 7.71Maxi 299
# Episode 2009	Average Score: 7.71
# Episode 2010	Average Score: 7.78Maxi 299
# Episode 2010	Average Score: 7.78
# Episode 2011	Average Score: 7.83Maxi 299
# Episode 2011	Average Score: 7.83
# Episode 2012	Average Score: 7.79Maxi 299
# Episode 2012	Average Score: 7.79
# Episode 2013	Average Score: 7.85Maxi 299
# Episode 2013	Average Score: 7.85
# Episode 2014	Average Score: 7.81Maxi 299
# Episode 2014	Average Score: 7.81
# Episode 2015	Average Score: 7.88Maxi 299
# Episode 2015	Average Score: 7.88
# Episode 2016	Average Score: 7.84Maxi 299
# Episode 2016	Average Score: 7.84
# Episode 2017	Average Score: 7.87Maxi 299
# Episode 2017	Average Score: 7.87
# Episode 2018	Average Score: 7.89Maxi 299
# Episode 2018	Average Score: 7.89
# Episode 2019	Average Score: 7.93Maxi 299
# Episode 2019	Average Score: 7.93
# Episode 2020	Average Score: 7.93Maxi 299
# Episode 2020	Average Score: 7.93
# Episode 2021	Average Score: 7.92Maxi 299
# Episode 2021	Average Score: 7.92
# Episode 2022	Average Score: 7.91Maxi 299
# Episode 2022	Average Score: 7.91
# Episode 2023	Average Score: 7.93Maxi 299
# Episode 2023	Average Score: 7.93
# Episode 2024	Average Score: 7.87Maxi 299
# Episode 2024	Average Score: 7.87
# Episode 2025	Average Score: 7.89Maxi 299
# Episode 2025	Average Score: 7.89
# Episode 2026	Average Score: 7.92Maxi 299
# Episode 2026	Average Score: 7.92
# Episode 2027	Average Score: 7.94Maxi 299
# Episode 2027	Average Score: 7.94
# Episode 2028	Average Score: 7.92Maxi 299
# Episode 2028	Average Score: 7.92
# Episode 2029	Average Score: 7.84Maxi 299
# Episode 2029	Average Score: 7.84
# Episode 2030	Average Score: 7.88Maxi 299
# Episode 2030	Average Score: 7.88
# Episode 2031	Average Score: 7.90Maxi 299
# Episode 2031	Average Score: 7.90
# Episode 2032	Average Score: 7.92Maxi 299
# Episode 2032	Average Score: 7.92
# Episode 2033	Average Score: 7.93Maxi 299
# Episode 2033	Average Score: 7.93
# Episode 2034	Average Score: 7.99Maxi 299
# Episode 2034	Average Score: 7.99
# Episode 2035	Average Score: 8.05Maxi 299
# Episode 2035	Average Score: 8.05
# Episode 2036	Average Score: 8.10Maxi 299
# Episode 2036	Average Score: 8.10
# Episode 2037	Average Score: 8.10Maxi 299
# Episode 2037	Average Score: 8.10
# Episode 2038	Average Score: 8.12Maxi 299
# Episode 2038	Average Score: 8.12
# Episode 2039	Average Score: 8.11Maxi 299
# Episode 2039	Average Score: 8.11
# Episode 2040	Average Score: 8.10Maxi 299
# Episode 2040	Average Score: 8.10
# Episode 2041	Average Score: 8.02Maxi 299
# Episode 2041	Average Score: 8.02
# Episode 2042	Average Score: 7.97Maxi 299
# Episode 2042	Average Score: 7.97
# Episode 2043	Average Score: 7.97Maxi 299
# Episode 2043	Average Score: 7.97
# Episode 2044	Average Score: 7.96Maxi 299
# Episode 2044	Average Score: 7.96
# Episode 2045	Average Score: 8.04Maxi 299
# Episode 2045	Average Score: 8.04
# Episode 2046	Average Score: 8.06Maxi 299
# Episode 2046	Average Score: 8.06
# Episode 2047	Average Score: 8.05Maxi 299
# Episode 2047	Average Score: 8.05
# Episode 2048	Average Score: 8.10Maxi 299
# Episode 2048	Average Score: 8.10
# Episode 2049	Average Score: 8.15Maxi 299
# Episode 2049	Average Score: 8.15
# Episode 2050	Average Score: 8.15Maxi 299
# Episode 2050	Average Score: 8.15
# Episode 2051	Average Score: 8.11Maxi 299
# Episode 2051	Average Score: 8.11
# Episode 2052	Average Score: 8.09Maxi 299
# Episode 2052	Average Score: 8.09
# Episode 2053	Average Score: 8.10Maxi 299
# Episode 2053	Average Score: 8.10
# Episode 2054	Average Score: 8.14Maxi 299
# Episode 2054	Average Score: 8.14
# Episode 2055	Average Score: 8.18Maxi 299
# Episode 2055	Average Score: 8.18
# Episode 2056	Average Score: 8.24Maxi 299
# Episode 2056	Average Score: 8.24
# Episode 2057	Average Score: 8.25Maxi 299
# Episode 2057	Average Score: 8.25
# Episode 2058	Average Score: 8.21Maxi 299
# Episode 2058	Average Score: 8.21
# Episode 2059	Average Score: 8.25Maxi 299
# Episode 2059	Average Score: 8.25
# Episode 2060	Average Score: 8.31Maxi 299
# Episode 2060	Average Score: 8.31
# Episode 2061	Average Score: 8.28Maxi 299
# Episode 2061	Average Score: 8.28
# Episode 2062	Average Score: 8.26Maxi 299
# Episode 2062	Average Score: 8.26
# Episode 2063	Average Score: 8.26Maxi 299
# Episode 2063	Average Score: 8.26
# Episode 2064	Average Score: 8.30Maxi 299
# Episode 2064	Average Score: 8.30
# Episode 2065	Average Score: 8.33Maxi 299
# Episode 2065	Average Score: 8.33
# Episode 2066	Average Score: 8.30Maxi 299
# Episode 2066	Average Score: 8.30
# Episode 2067	Average Score: 8.30Maxi 299
# Episode 2067	Average Score: 8.30
# Episode 2068	Average Score: 8.33Maxi 299
# Episode 2068	Average Score: 8.33
# Episode 2069	Average Score: 8.34Maxi 299
# Episode 2069	Average Score: 8.34
# Episode 2070	Average Score: 8.32Maxi 299
# Episode 2070	Average Score: 8.32
# Episode 2071	Average Score: 8.34Maxi 299
# Episode 2071	Average Score: 8.34
# Episode 2072	Average Score: 8.35Maxi 299
# Episode 2072	Average Score: 8.35
# Episode 2073	Average Score: 8.38Maxi 299
# Episode 2073	Average Score: 8.38
# Episode 2074	Average Score: 8.38Maxi 299
# Episode 2074	Average Score: 8.38
# Episode 2075	Average Score: 8.38Maxi 299
# Episode 2075	Average Score: 8.38
# Episode 2076	Average Score: 8.38Maxi 299
# Episode 2076	Average Score: 8.38
# Episode 2077	Average Score: 8.35Maxi 299
# Episode 2077	Average Score: 8.35
# Episode 2078	Average Score: 8.33Maxi 299
# Episode 2078	Average Score: 8.33
# Episode 2079	Average Score: 8.40Maxi 299
# Episode 2079	Average Score: 8.40
# Episode 2080	Average Score: 8.38Maxi 299
# Episode 2080	Average Score: 8.38
# Episode 2081	Average Score: 8.38Maxi 299
# Episode 2081	Average Score: 8.38
# Episode 2082	Average Score: 8.37Maxi 299
# Episode 2082	Average Score: 8.37
# Episode 2083	Average Score: 8.40Maxi 299
# Episode 2083	Average Score: 8.40
# Episode 2084	Average Score: 8.37Maxi 299
# Episode 2084	Average Score: 8.37
# Episode 2085	Average Score: 8.35Maxi 299
# Episode 2085	Average Score: 8.35
# Episode 2086	Average Score: 8.30Maxi 299
# Episode 2086	Average Score: 8.30
# Episode 2087	Average Score: 8.25Maxi 299
# Episode 2087	Average Score: 8.25
# Episode 2088	Average Score: 8.30Maxi 299
# Episode 2088	Average Score: 8.30
# Episode 2089	Average Score: 8.25Maxi 299
# Episode 2089	Average Score: 8.25
# Episode 2090	Average Score: 8.17Maxi 299
# Episode 2090	Average Score: 8.17
# Episode 2091	Average Score: 8.19Maxi 299
# Episode 2091	Average Score: 8.19
# Episode 2092	Average Score: 8.16Maxi 299
# Episode 2092	Average Score: 8.16
# Episode 2093	Average Score: 8.09Maxi 299
# Episode 2093	Average Score: 8.09
# Episode 2094	Average Score: 8.05Maxi 299
# Episode 2094	Average Score: 8.05
# Episode 2095	Average Score: 8.05Maxi 299
# Episode 2095	Average Score: 8.05
# Episode 2096	Average Score: 8.05Maxi 299
# Episode 2096	Average Score: 8.05
# Episode 2097	Average Score: 8.01Maxi 299
# Episode 2097	Average Score: 8.01
# Episode 2098	Average Score: 7.89Maxi 299
# Episode 2098	Average Score: 7.89
# Episode 2099	Average Score: 7.93Maxi 299
# Episode 2099	Average Score: 7.93
# Episode 2100	Average Score: 7.96Maxi 299
# Episode 2100	Average Score: 7.96
# Episode 2101	Average Score: 7.97Maxi 299
# Episode 2101	Average Score: 7.97
# Episode 2102	Average Score: 8.02Maxi 299
# Episode 2102	Average Score: 8.02
# Episode 2103	Average Score: 8.04Maxi 299
# Episode 2103	Average Score: 8.04
# Episode 2104	Average Score: 8.08Maxi 299
# Episode 2104	Average Score: 8.08
# Episode 2105	Average Score: 8.01Maxi 299
# Episode 2105	Average Score: 8.01
# Episode 2106	Average Score: 8.05Maxi 299
# Episode 2106	Average Score: 8.05
# Episode 2107	Average Score: 8.07Maxi 299
# Episode 2107	Average Score: 8.07
# Episode 2108	Average Score: 8.08Maxi 299
# Episode 2108	Average Score: 8.08
# Episode 2109	Average Score: 7.99Maxi 299
# Episode 2109	Average Score: 7.99
# Episode 2110	Average Score: 7.86Maxi 299
# Episode 2110	Average Score: 7.86
# Episode 2111	Average Score: 7.86Maxi 299
# Episode 2111	Average Score: 7.86
# Episode 2112	Average Score: 7.90Maxi 299
# Episode 2112	Average Score: 7.90
# Episode 2113	Average Score: 7.88Maxi 299
# Episode 2113	Average Score: 7.88
# Episode 2114	Average Score: 7.89Maxi 299
# Episode 2114	Average Score: 7.89
# Episode 2115	Average Score: 7.87Maxi 299
# Episode 2115	Average Score: 7.87
# Episode 2116	Average Score: 7.82Maxi 299
# Episode 2116	Average Score: 7.82
# Episode 2117	Average Score: 7.75Maxi 299
# Episode 2117	Average Score: 7.75
# Episode 2118	Average Score: 7.64Maxi 299
# Episode 2118	Average Score: 7.64
# Episode 2119	Average Score: 7.59Maxi 299
# Episode 2119	Average Score: 7.59
# Episode 2120	Average Score: 7.63Maxi 299
# Episode 2120	Average Score: 7.63
# Episode 2121	Average Score: 7.66Maxi 299
# Episode 2121	Average Score: 7.66
# Episode 2122	Average Score: 7.67Maxi 299
# Episode 2122	Average Score: 7.67
# Episode 2123	Average Score: 7.62Maxi 299
# Episode 2123	Average Score: 7.62
# Episode 2124	Average Score: 7.69Maxi 299
# Episode 2124	Average Score: 7.69
# Episode 2125	Average Score: 7.72Maxi 299
# Episode 2125	Average Score: 7.72
# Episode 2126	Average Score: 7.72Maxi 299
# Episode 2126	Average Score: 7.72
# Episode 2127	Average Score: 7.80Maxi 299
# Episode 2127	Average Score: 7.80
# Episode 2128	Average Score: 7.89Maxi 299
# Episode 2128	Average Score: 7.89
# Episode 2129	Average Score: 7.87Maxi 299
# Episode 2129	Average Score: 7.87
# Episode 2130	Average Score: 7.92Maxi 299
# Episode 2130	Average Score: 7.92
# Episode 2131	Average Score: 7.90Maxi 299
# Episode 2131	Average Score: 7.90
# Episode 2132	Average Score: 7.93Maxi 299
# Episode 2132	Average Score: 7.93
# Episode 2133	Average Score: 7.91Maxi 299
# Episode 2133	Average Score: 7.91
# Episode 2134	Average Score: 7.86Maxi 299
# Episode 2134	Average Score: 7.86
# Episode 2135	Average Score: 7.86Maxi 299
# Episode 2135	Average Score: 7.86
# Episode 2136	Average Score: 7.80Maxi 299
# Episode 2136	Average Score: 7.80
# Episode 2137	Average Score: 7.79Maxi 299
# Episode 2137	Average Score: 7.79
# Episode 2138	Average Score: 7.73Maxi 299
# Episode 2138	Average Score: 7.73
# Episode 2139	Average Score: 7.80Maxi 299
# Episode 2139	Average Score: 7.80
# Episode 2140	Average Score: 7.79Maxi 299
# Episode 2140	Average Score: 7.79
# Episode 2141	Average Score: 7.88Maxi 299
# Episode 2141	Average Score: 7.88
# Episode 2142	Average Score: 7.90Maxi 299
# Episode 2142	Average Score: 7.90
# Episode 2143	Average Score: 7.93Maxi 299
# Episode 2143	Average Score: 7.93
# Episode 2144	Average Score: 7.85Maxi 299
# Episode 2144	Average Score: 7.85
# Episode 2145	Average Score: 7.79Maxi 299
# Episode 2145	Average Score: 7.79
# Episode 2146	Average Score: 7.73Maxi 299
# Episode 2146	Average Score: 7.73
# Episode 2147	Average Score: 7.69Maxi 299
# Episode 2147	Average Score: 7.69
# Episode 2148	Average Score: 7.65Maxi 299
# Episode 2148	Average Score: 7.65
# Episode 2149	Average Score: 7.66Maxi 299
# Episode 2149	Average Score: 7.66
# Episode 2150	Average Score: 7.66Maxi 299
# Episode 2150	Average Score: 7.66
# Episode 2151	Average Score: 7.70Maxi 299
# Episode 2151	Average Score: 7.70
# Episode 2152	Average Score: 7.72Maxi 299
# Episode 2152	Average Score: 7.72
# Episode 2153	Average Score: 7.68Maxi 299
# Episode 2153	Average Score: 7.68
# Episode 2154	Average Score: 7.65Maxi 299
# Episode 2154	Average Score: 7.65
# Episode 2155	Average Score: 7.62Maxi 299
# Episode 2155	Average Score: 7.62
# Episode 2156	Average Score: 7.55Maxi 299
# Episode 2156	Average Score: 7.55
# Episode 2157	Average Score: 7.57Maxi 299
# Episode 2157	Average Score: 7.57
# Episode 2158	Average Score: 7.63Maxi 299
# Episode 2158	Average Score: 7.63
# Episode 2159	Average Score: 7.70Maxi 299
# Episode 2159	Average Score: 7.70
# Episode 2160	Average Score: 7.64Maxi 299
# Episode 2160	Average Score: 7.64
# Episode 2161	Average Score: 7.63Maxi 299
# Episode 2161	Average Score: 7.63
# Episode 2162	Average Score: 7.61Maxi 299
# Episode 2162	Average Score: 7.61
# Episode 2163	Average Score: 7.70Maxi 299
# Episode 2163	Average Score: 7.70
# Episode 2164	Average Score: 7.66Maxi 299
# Episode 2164	Average Score: 7.66
# Episode 2165	Average Score: 7.63Maxi 299
# Episode 2165	Average Score: 7.63
# Episode 2166	Average Score: 7.62Maxi 299
# Episode 2166	Average Score: 7.62
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-f0c4fff1baba> in <module>
#      51     return scores
#      52
# ---> 53 scores = dqn()
#      54
#      55 # plot the scores
#
# <ipython-input-21-f0c4fff1baba> in dqn(n_episodes, max_t, eps_start, eps_end, eps_decay)
#      30             reward = env_info.rewards[0]
#      31             done = env_info.local_done[0]
# ---> 32             agent.step(state, action, reward, next_state, done)
#      33             #print(state, action, reward, next_state, done)
#      34             state = next_state
#
# <ipython-input-17-27c65bdd7430> in step(self, state, action, reward, next_state, done)
#      65                 #experiences = self.memory.sample(ALPHA2,beta)
#      66                 for _ in range(N_Update_per):
# ---> 67                     experiences = self.memory.sample_idx()
#      68                     self.learn(experiences, GAMMA)
#      69
#
# <ipython-input-17-27c65bdd7430> in sample_idx(self)
#     263         index_value = random.sample(list(enumerate(self.memory)), k=self.batch_size)
#     264         #print("batch", self.batch_size)
# --> 265         states = torch.from_numpy(np.stack([[self.memory[e[0]-2].state,self.memory[e[0]-1].state ,e[1].state] for e in index_value if e is not None and e[1].done != True and self.memory[e[0]-1].done != True and e[0]-1 > 0 and e[0] < len(agent.memory.memory)-1] , axis = 0 )).float().to(device)
#     266         actions = torch.from_numpy(np.vstack([e[1].action for e in index_value if e is not None and e[1].done != True and self.memory[e[0]-1].done != True and e[0]-1 > 0 and e[0] < len(agent.memory.memory)-1])).long().to(device)
#     267         rewards = torch.from_numpy(np.vstack([e[1].reward for e in index_value if e is not None and e[1].done != True and self.memory[e[0]-1].done != True and e[0]-1 > 0 and e[0] < len(agent.memory.memory)-1])).float().to(device)
#
# RuntimeError: [enforce fail at ..\c10\core\CPUAllocator.cpp:72] data. DefaultCPUAllocator: not enough memory: you tried to allocate 3810240 bytes. Buy new RAM!

# %%
print("the length of " , len(agent.memory.memory) , int(1e5),len(agent.memory.memory) /int(1e5))
# Out:
# the length of  34158 100000 0.34158

# %%
# i = agent.memory.sample_idx()
# x = agent.memory.sample_idx_withBatch(3)
# print("length", len(agent.memory.memory) , "size", getsizeof(agent.memory.memory), "total memory required for REPLAY BUFFER", getsizeof(agent.memory.memory[1]) * BUFFER_SIZE)
# p = agent.memory.sample()
# print(np.shape(i[0]))
# print("normal", i[0].view(15,-1,84,84).size())
print(agent.qnetwork_local)
kernels = agent.qnetwork_local.conv1.weight.detach()

kernels2 = agent.qnetwork_local.conv2.weight.detach()
print("kernels", kernels.size(), kernels.size(0),"adjusted kernels", np.shape(kernels[1,0:3,:]) )
fig, axarr = plt.subplots(kernels.size(0))
fig1, axarr1 = plt.subplots(kernels.size(0))
fig2, axarr2 = plt.subplots(kernels.size(0))
print(kernels , kernels2)
for idx in range(kernels.size(0)):
    axarr[idx].imshow(kernels[idx ,0:3,:].view(5,5,-1).cpu())
    axarr1[idx].imshow(kernels[idx,3:6].view(5,5,-1).cpu())
    axarr2[idx].imshow(kernels[idx,6:9,:].view(5,5,-1).cpu())

# %% [markdown]
# When finished, you can close the environment.

# %%
env.close()

# %%
i = agent.memory.sample_idx()
x = agent.memory.sample_idx_withBatch(3)
print("length", len(agent.memory.memory) , "size", getsizeof(agent.memory.memory), "total memory required for REPLAY BUFFER", getsizeof(agent.memory.memory[1]) * BUFFER_SIZE)
p = agent.memory.sample()
print(np.shape(i[0]))
print("normal", i[0].view(32,-1,84,84).size())
input_ = i[0]
(states, action, n_state, reward , dones) = i
print(states.size())
batch_one = states[2]
print("batch", batch_one.size())
im_1 = batch_one[0]
im_2 = batch_one[1]
im_3 = batch_one[2]
print("shape", im_1.permute(1, 2, 0).size())
plt.imshow(im_1.view(84,84,3).cpu())
plt.show()
plt.imshow(im_2.view(84,84,3).cpu())
plt.show()
plt.imshow(im_3.view(84,84,3).cpu())
plt.show()

# %%
batch_one = states[3]
print("batch", batch_one.size())
im_1 = batch_one[0]
im_2 = batch_one[1]
im_3 = batch_one[2]
print("shape", im_1.permute(1, 2, 0).size())
plt.imshow(im_1.view(84,84,3).cpu())
plt.show()
plt.imshow(im_2.view(84,84,3).cpu())
plt.show()
plt.imshow(im_3.view(84,84,3).cpu())
plt.show()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  A few **important notes**:
# - When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```
# - To structure your work, you're welcome to work directly in this Jupyter notebook, or you might like to start over with a new file!  You can see the list of files in the workspace by clicking on **_Jupyter_** in the top left corner of the notebook.
# - In this coding environment, you will not be able to watch the agent while it is training.  However, **_after training the agent_**, you can download the saved model weights to watch the agent on your own machine!

# %%
batch_one = states[4]
print("batch", batch_one.size())
im_1 = batch_one[0]
im_2 = batch_one[1]
im_3 = batch_one[2]
print("shape", im_1.permute(1, 2, 0).size())
plt.imshow(im_1.view(84,84,3).cpu())
plt.show()
plt.imshow(im_2.view(84,84,3).cpu())
plt.show()
plt.imshow(im_3.view(84,84,3).cpu())
plt.show()
